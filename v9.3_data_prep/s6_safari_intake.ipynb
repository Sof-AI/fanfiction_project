# %% [markdown]
# # Cleaning s6 intaking urls from Safari reading list
# - **By:** Sofia Kobayashi
# - **Date:** 11/18/2023
# - **Description:** Intaking urls from the Safari reading lists

# %%
import pandas as pd
import re
import AO3
import json
import plistlib
from datetime import datetime
import re

import os
from dotenv import load_dotenv
from pathlib import Path
env_path = Path(".") / ".env"
load_dotenv(dotenv_path=env_path)

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Load in reading list

# %%
def readingListToJson():
    now = datetime.now()
    current_date = now.strftime("%m-%d-%y")

    INPUT_FILE  = os.path.join(os.environ['HOME'], 'Library/Safari/Bookmarks.plist')
    OUTPUT_FILE = f"reading_lists/readinglist_{current_date}.json"

    # Load and parse the Bookmarks file
    with open(INPUT_FILE, 'rb') as plist_file:
        plist = plistlib.load(plist_file)

    # Look for the child node which contains the Reading List data.
    # There should only be one Reading List item
    children = plist['Children']
    for child in children:
        if child.get('Title', None) == 'com.apple.ReadingList':
            reading_list = child

    # Extract the bookmarks
    bookmarks = reading_list['Children']

    # For each bookmark in the bookmark list, grab the URL, dateAdded & dateLastViewed
    urls = []

    for bookmark in bookmarks:
        temp = {}
        temp["url"] = bookmark["URLString"]
        temp["dateAdded"] = bookmark["ReadingList"]["DateAdded"].strftime("%m-%d-%y %H:%M:%S")
        temp["dateLastViewed"] = bookmark["ReadingList"].get("DateLastViewed")
        if temp["dateLastViewed"] != None: temp["dateLastViewed"] = temp["dateLastViewed"]\
            .strftime("%m-%d-%y %H:%M:%S")
        urls.append(temp)

    # Write the URLs to a file
    with open(OUTPUT_FILE, "w") as outfile:
        json.dump(urls, outfile)

    print(f'Created new readinglist in "{OUTPUT_FILE}"')
    return OUTPUT_FILE

# %%
# Intake new reading list
FILE = readingListToJson()

with open(FILE, 'r') as infile:
    rl = json.load(infile)
# Out:
# Created new readinglist in "reading_lists/readinglist_12-06-23.json"

# %% [markdown]
# ### De-dup reading list

# %%
# ELEPHANT - USE JSON FOR NOW, EVENTUALLY SWITCH TO LOADING IN ALL CURRENT DBs & SCRAPING FROM THERE

# %%
# De-dup against ALL pre-processed links (old storage JSON)
with open('reading_lists/already_seen_urls.json') as infile: 
    already_seen = json.load(infile)
    already_seen_urls = set([pair['url'] for pair in already_seen])

rl_dedup = []
for info in rl:
    if info['url'] not in already_seen_urls:
        info['dateProcessed'] = datetime.now().strftime("%m-%d-%y %H:%M:%S")
        rl_dedup.append(info)

# rl_dedup

# %% [markdown]
# ### Sort into ao3, other fanfic other else
# - Initialize ao3 df

# %%
# Sort into AO3, other fanfiction (ffn.net, Wattpad, tumblr, etc), everything else
ao3_list = []
other_fanfic = []
other_else = []

for info in rl_dedup:
    if 'archiveofourown.org' in info['url']:
        ao3_list.append(info)
        
    for dom in ['fanfiction.net', 'wattpad.com', 'tumblr.com', 'facebook.com']:
        if dom in info['url']:
            other_fanfic.append(info)
            break
    else:
        other_else.append(info)

# set([pair['url'].split('/')[2] for pair in other_fanfic])

# %%
# Initialize ao3 df
ao3 = pd.DataFrame(ao3_list)
ao3['is_new'] = True

# %% [markdown]
# ### Sort ao3 links into type

# %%
# Divide urls by ao3_type
def ao3_type(url):
    ao3_type = re.compile('archiveofourown.org/(\w+)(.{1})').findall(url)[0]
    
    if ao3_type[1] == '?':
        return ({'url_type': ao3_type[0], 'type': 'query'})  
    elif ao3_type[0] == 'bookmarks': # easy
        return ({'url_type': 'bookmarks', 'type': 'bookmarks'})
    
    elif ao3_type[0] == 'chapters':
        return ({'url_type': 'chapters', 'type': 'works'})
    
    elif ao3_type[0] == 'collections': 
        if '/works/' in url:
            return ({'url_type': 'collections', 'type': 'works'})
        else:
            return ({'url_type': 'collections', 'type': 'collections'})
    
    elif ao3_type[0] == 'comments': # easy
        return ({'url_type': 'comments', 'type': 'comments'})
    
    elif ao3_type[0] == 'external_works': # easy
        return ({'url_type': 'external_works', 'type': 'external_works'})
    
    elif ao3_type[0] == 'fandoms': # easy
        return ({'url_type': 'fandoms', 'type': 'tags'})
    
    elif ao3_type[0] == 'series': # easy
        return ({'url_type': 'series', 'type': 'series'})
    
    elif ao3_type[0] == 'tags': # easy
        return ({'url_type': 'tags', 'type': 'tags'})
    
    elif ao3_type[0] == 'users': # easy
        return ({'url_type': 'users', 'type': 'users'})
    
    elif ao3_type[0] == 'works':
        return ({'url_type': 'works', 'type': 'works'})

# %%
# Fill ao3 type col
for ind in ao3.index:
    types = ao3_type(ao3.loc[ind, 'url'])
    ao3.loc[ind, 'url_type'] = types['url_type']
    ao3.loc[ind, 'type'] = types['type']

# %%
ao3.type.value_counts()
# ao3[ao3.type=='chapters']
# Out:
# type
# works             2904
# series             135
# users               71
# tags                34
# collections          9
# query                4
# external_works       1
# comments             1
# Name: count, dtype: int64

# %%
sorted(ao3.type.value_counts().index)
# Out:
# ['collections',
#  'comments',
#  'external_works',
#  'query',
#  'series',
#  'tags',
#  'users',
#  'works']

# %% [markdown]
# ## Handling Each Type

# %% [markdown]
# ### Handling 'collections'
# - Get collection name

# %%
collections = ao3[ao3.type=='collections'].reset_index(drop=True)

# Get collection name col
for ind in collections.index:
    url = collections.loc[ind, 'url']
    search = re.compile('/collections/(\w+)').findall(url)[0]
    collections.loc[ind, 'id'] = search

    
collections = collections[['id', 'url_type', 'type', 'url', 'dateProcessed', 
                           'dateAdded', 'dateLastViewed', 'is_new']]
collections.head()
# Out:
#                        id     url_type         type  \
# 0               atla_simp  collections  collections
# 1       Heavenly_Treasury  collections  collections
# 2                SJ_Reset  collections  collections
# 3  TimeTravel_WorldTravel  collections  collections
# 4       TheCrackheadBible  collections  collections
#
#                                                  url      dateProcessed  \
# 0  https://archiveofourown.org/collections/atla_simp  11-22-23 14:20:07
# 1  https://archiveofourown.org/collections/Heaven...  11-22-23 14:20:07
# 2  https://archiveofourown.org/collections/SJ_Res...  11-22-23 14:20:07
# 3  https://archiveofourown.org/collections/TimeTr...  11-22-23 14:20:07
# 4  https://archiveofourown.org/collections/TheCra...  11-22-23 14:20:07
#
#            dateAdded dateLastViewed  is_new
# 0  04-29-23 18:16:47           None    True
# 1  03-08-23 14:14:18           None    True
# 2  02-11-23 20:58:11           None    True
# 3  01-06-23 07:42:54           None    True
# 4  03-30-22 23:44:32           None    True

# %% [markdown]
# ### Handling 'comments'
# - No handling

# %%
comments = ao3[ao3.type=='comments'].reset_index(drop=True)
comments = comments[['url_type', 'type', 'url', 'dateProcessed', 'dateAdded', 'dateLastViewed', 'is_new']]
comments
# Out:
#    url_type      type                                             url  \
# 0  comments  comments  https://archiveofourown.org/comments/215664449
#
#        dateProcessed          dateAdded dateLastViewed  is_new
# 0  11-22-23 14:20:07  11-11-22 03:43:45           None    True

# %% [markdown]
# ### Handling 'external_works'
# - url types: external_works
# - Manually get referenced work

# %%
# Process chapter
external_works = ao3[ao3.url_type=='external_works'].reset_index(drop=True)\
                                                    .rename(columns={'url': 'external_url'})
external_works['url'] = ['https://www.fanfiction.net/s/12334156/4/Travelers']
external_works

have to hand-process these
# Out:
#                                         external_url          dateAdded  \
# 0  https://archiveofourown.org/external_works/637417  01-02-22 07:33:23
#
#   dateLastViewed      dateProcessed  is_new        url_type            type  \
# 0           None  11-22-23 14:20:07    True  external_works  external_works
#
#                                                  url
# 0  https://www.fanfiction.net/s/12334156/4/Travelers

# %% [markdown]
# ### Handling 'query'
# - No handling

# %%
query = ao3[ao3.type=='query'].reset_index(drop=True)

query = query[['url_type', 'type', 'url', 'dateProcessed', 'dateAdded', 'dateLastViewed', 'is_new']]
query
# Out:
#     url_type   type                                                url  \
# 0      works  query  https://archiveofourown.org/works?commit=Sort+...
# 1  bookmarks  query  https://archiveofourown.org/bookmarks?commit=S...
# 2      works  query  https://archiveofourown.org/works?commit=Sort+...
# 3      works  query  https://archiveofourown.org/works?commit=Sort+...
#
#        dateProcessed          dateAdded     dateLastViewed  is_new
# 0  11-22-23 14:20:07  03-09-23 16:13:44               None    True
# 1  11-22-23 14:20:07  11-23-22 00:49:33               None    True
# 2  11-22-23 14:20:07  10-09-22 20:43:07  10-10-22 13:53:54    True
# 3  11-22-23 14:20:07  08-06-22 07:36:29               None    True

# %% [markdown]
# ### Handling 'series'
# - url types: series
# - Add series id

# %%
series = ao3[ao3.type=='series'].reset_index(drop=True)

# Add series id
for ind in series.index:
    url = series.loc[ind, 'url']
    search = re.compile('series/(\d+)').findall(url)[0]
    series.loc[ind, 'id'] = search

series = series[['id', 'url_type', 'type', 'url', 'dateProcessed', 'dateAdded', 'dateLastViewed', 'is_new']]
series.head()
# Out:
#         id url_type    type                                         url  \
# 0  3226068   series  series  https://archiveofourown.org/series/3226068
# 1  3606640   series  series  https://archiveofourown.org/series/3606640
# 2  1600705   series  series  https://archiveofourown.org/series/1600705
# 3   824460   series  series   https://archiveofourown.org/series/824460
# 4  3509641   series  series  https://archiveofourown.org/series/3509641
#
#        dateProcessed          dateAdded dateLastViewed  is_new
# 0  11-22-23 14:20:07  11-12-23 09:29:43           None    True
# 1  11-22-23 14:20:07  11-10-23 08:31:49           None    True
# 2  11-22-23 14:20:07  11-04-23 11:35:44           None    True
# 3  11-22-23 14:20:07  10-24-23 20:02:31           None    True
# 4  11-22-23 14:20:07  09-29-23 11:40:54           None    True

# %% [markdown]
# ### Handling 'tags'
# - url types: fandoms, tags
# - Parse & add tag text

# %%
from urllib.parse import unquote
tags = ao3[ao3.type=='tags'].reset_index(drop=True)

# Add tag text
for ind in tags.index:
    url = tags.loc[ind, 'url']
    search = re.compile('/(tags|fandoms)/(.+)(/works|$)').findall(url)[0][1].split('/works')[0]
    tags.loc[ind, 'text'] = unquote(search)

tags = tags[['url_type', 'type', 'url', 'text', 'dateProcessed', 'dateAdded', 'dateLastViewed', 'is_new']]
tags.head()
# Out:
#   url_type  type                                                url  \
# 0     tags  tags   https://archiveofourown.org/tags/Haikyuu!!/works
# 1     tags  tags  https://archiveofourown.org/tags/212th%20Attac...
# 2     tags  tags  https://archiveofourown.org/tags/Code%20Geass/...
# 3     tags  tags  https://archiveofourown.org/tags/Top%20Gun%20(...
# 4  fandoms  tags  http://archiveofourown.org/fandoms/The%20Schoo...
#
#                                                 text      dateProcessed  \
# 0                                          Haikyuu!!  11-22-23 14:20:07
# 1  212th Attack Battalion Members (Star Wars: The...  11-22-23 14:20:07
# 2                                         Code Geass  11-22-23 14:20:07
# 3                                   Top Gun (Movies)  11-22-23 14:20:07
# 4      The School for Good and Evil - Soman Chainani  11-22-23 14:20:07
#
#            dateAdded dateLastViewed  is_new
# 0  10-08-23 07:11:09           None    True
# 1  08-27-23 09:23:00           None    True
# 2  08-22-23 07:21:44           None    True
# 3  07-23-23 03:24:06           None    True
# 4  04-16-23 18:42:20           None    True

# %% [markdown]
# ### Handling 'users'
# - url types: users
# - Parse & Add user pen name (id)

# %%
users = ao3[ao3.type=='users'].reset_index(drop=True)

# Add user pen name (id)
for ind in users.index:
    url = users.loc[ind, 'url']
    search = re.compile('users/(\w+)').findall(url)[0]
    users.loc[ind, 'id'] = search

users = users[['id','url_type', 'type', 'url', 'dateProcessed', 'dateAdded', 'dateLastViewed', 'is_new']]
users.head()
# Out:
#                     id url_type   type  \
# 0  indefinitelyforever    users  users
# 1    Kaeyas_thighs_tho    users  users
# 2               naarii    users  users
# 3              azunshi    users  users
# 4          RisqueRaven    users  users
#
#                                                  url      dateProcessed  \
# 0  https://archiveofourown.org/users/indefinitely...  11-22-23 14:20:07
# 1  https://archiveofourown.org/users/Kaeyas_thigh...  11-22-23 14:20:07
# 2  https://archiveofourown.org/users/naarii/pseud...  11-22-23 14:20:07
# 3  https://archiveofourown.org/users/azunshi/pseu...  11-22-23 14:20:07
# 4  https://archiveofourown.org/users/RisqueRaven/...  11-22-23 14:20:07
#
#            dateAdded     dateLastViewed  is_new
# 0  11-03-23 02:03:58               None    True
# 1  10-31-23 22:39:22  11-03-23 00:44:03    True
# 2  10-05-23 22:18:40               None    True
# 3  09-26-23 21:51:13               None    True
# 4  09-05-23 08:36:59               None    True

# %% [markdown]
# ### Handling 'works'
# - chapters, col_work, works

# %%
# Process chapter
chapters = ao3[ao3.url_type=='chapters'].reset_index(drop=True).rename(columns={'url': 'chapter_url'})
chapters['url'] = []

for ind in chapters.index:
    url = chapters.loc[ind, 'url']
    search = re.compile('/works/(\d+)').findall(url)[0]
    chapters.loc[ind, 'id'] = search

chapters

have to hand-process these
# Out:
# Empty DataFrame
# Columns: [chapter_url, dateAdded, dateLastViewed, dateProcessed, is_new, url_type, type, url]
# Index: []

# %%
col_work = ao3[(ao3.url_type=='collections') & (ao3.type == 'works')].reset_index(drop=True)

# Fill from_collection
for ind in col_work.index:
    url = col_work.loc[ind, 'url']
    
    search = re.compile('/works/(\d+)').findall(url)[0]
    col_work.loc[ind, 'id'] = search
    
    search = re.compile('/collections/(\w+)').findall(url)[0]
    col_work.loc[ind, 'from_collection'] = search

col_work.head()
# Out:
#                                                  url          dateAdded  \
# 0  https://archiveofourown.org/collections/Whynot...  08-22-23 07:18:47
# 1  https://archiveofourown.org/collections/Whynot...  08-22-23 07:18:07
# 2  https://archiveofourown.org/collections/Whynot...  08-22-23 07:16:38
# 3  https://archiveofourown.org/collections/Whynot...  08-22-23 07:16:12
# 4  https://archiveofourown.org/collections/Whynot...  08-22-23 07:14:47
#
#   dateLastViewed      dateProcessed  is_new     url_type   type        id  \
# 0           None  11-22-23 14:20:07    True  collections  works  18530821
# 1           None  11-22-23 14:20:07    True  collections  works  39376755
# 2           None  11-22-23 14:20:07    True  collections  works  24311155
# 3           None  11-22-23 14:20:07    True  collections  works  42481512
# 4           None  11-22-23 14:20:07    True  collections  works  36456823
#
#   from_collection
# 0   Whynotearlier
# 1   Whynotearlier
# 2   Whynotearlier
# 3   Whynotearlier
# 4   Whynotearlier

# %%
works = ao3[(ao3.url_type=='works') & (ao3.type=='works')].reset_index(drop=True)

# Fill id
for ind in works.index:
    url = works.loc[ind, 'url']
    search = re.compile('/works/(\w+)').findall(url)[0]
    works.loc[ind, 'id'] = search

# Concatenate chapters, col_works, and works into works DF
works = pd.concat([chapters, col_work, works])
works = works[['id','url_type', 'type', 'url', 'from_collection', 'chapter_url', 
               'dateProcessed', 'dateAdded', 'dateLastViewed', 'is_new']]
works['is_new'] = True

works.head()
# Out:
#          id     url_type   type  \
# 0  18530821  collections  works
# 1  39376755  collections  works
# 2  24311155  collections  works
# 3  42481512  collections  works
# 4  36456823  collections  works
#
#                                                  url from_collection  \
# 0  https://archiveofourown.org/collections/Whynot...   Whynotearlier
# 1  https://archiveofourown.org/collections/Whynot...   Whynotearlier
# 2  https://archiveofourown.org/collections/Whynot...   Whynotearlier
# 3  https://archiveofourown.org/collections/Whynot...   Whynotearlier
# 4  https://archiveofourown.org/collections/Whynot...   Whynotearlier
#
#   chapter_url      dateProcessed          dateAdded dateLastViewed  is_new
# 0         NaN  11-22-23 14:20:07  08-22-23 07:18:47           None    True
# 1         NaN  11-22-23 14:20:07  08-22-23 07:18:07           None    True
# 2         NaN  11-22-23 14:20:07  08-22-23 07:16:38           None    True
# 3         NaN  11-22-23 14:20:07  08-22-23 07:16:12           None    True
# 4         NaN  11-22-23 14:20:07  08-22-23 07:14:47           None    True

# %%
## Merge with current AO3 databases

# %%
# Merge with current AO3 dtb

# %% [markdown]
# ## Load in new AO3 stuff & update DBs
# - works, series, collections(?), users(?)

# %%
# Load in new AO3

# %% [markdown]
# # Workspace

# %%
df = pd.read_csv('fic_url_clean_1.csv', encoding='utf-8', index_col=0)
d = []
for u in df.url:
    d.append({'url': u})

# %%
df = pd.read_csv('../v9.2_jupyter-ffnv9/checkpoints_data/all_ao3_links_until_01-13-23__02-26-23.csv', encoding='utf-8', index_col=0)
d = []
for u in df.url:
    d.append({'url': u})

# %%
def all_types_test(reading_list):
    """
    Takes a reading list style list of ao3 info.
    Returns all ao3 types present in list.
    """
    count = set()
    for info in reading_list:
        ao3_type = re.compile('archiveofourown.org/(\w+)(.{1})').findall(info['url'])[0]
        count.add(ao3_type)
        if ao3_type[0] == 'bookmarks':
            print(info['url'])
        
    return sorted(count, key=lambda x: x[0])

all_types_test(d)
# Out:
# https://archiveofourown.org/bookmarks?commit=Sort+and+Filter&bookmark_search%5Bsort_column%5D=created_at&include_bookmark_search%5Brelationship_ids%5D%5B%5D=27817261&bookmark_search%5Bother_tag_names%5D=&bookmark_search%5Bother_bookmark_tag_names%5D=&bookmark_search%5Bexcluded_tag_names%5D=&bookmark_search%5Bexcluded_bookmark_tag_names%5D=&bookmark_search%5Bbookmarkable_query%5D=&bookmark_search%5Bbookmark_query%5D=&bookmark_search%5Blanguage_id%5D=&bookmark_search%5Brec%5D=0&bookmark_search%5Bwith_notes%5D=0&user_id=kyme
# [('bookmarks', '?'),
#  ('chapters', '/'),
#  ('collections', '/'),
#  ('comments', '/'),
#  ('series', '/'),
#  ('tags', '/'),
#  ('users', '/'),
#  ('works', '/'),
#  ('works', '?')]

# %%
# total = set()
# for info in ao3:
#     t = ao3_type(info['url'])
#     if t == None:
#         print(info)
#     total.add(t)

# total

# %%
df2 = pd.read_csv('clean_data_4/all_versions_fic_url.csv', index_col=0, encoding='utf-8')

# %%
df2[~pd.isnull(df2.title)]
# Out:
#       version_num      smk_source dtb_type location  fic_id  \
# 579           7.0      v7_updates  to_read      ao3     NaN
# 960           7.1        v7.1_ffn     read      ao3     NaN
# 611           7.0      v7_updates  to_read      ao3     NaN
# 584           7.0      v7_updates  to_read      ao3     NaN
# 514           7.0      v7_updates  to_read      ao3     NaN
# ...           ...             ...      ...      ...     ...
# 3852          8.0  v8_local_files      NaN      oth     NaN
# 1535          8.0          chrome      NaN      oth     NaN
# 3853          8.0  v8_local_files      NaN      oth     NaN
# 3854          8.0  v8_local_files      NaN      oth     NaN
# 268           7.0       v7_toread  to_read      oth     NaN
#
#                                                     url categories is_bold  \
# 579   http://archiveofourown.org/works/260273/chapte...        NaN   False
# 960   https://archiveofourown.org/works/717740/chapt...        NaN     NaN
# 611   https://archiveofourown.org/collections/best_i...        NaN   False
# 584   https://archiveofourown.org/collections/bnhafi...        NaN   False
# 514   https://archiveofourown.org/collections/Clever...        NaN   False
# ...                                                 ...        ...     ...
# 3852  https://www.royalroad.com/fiction/36735/the-pe...        NaN     NaN
# 1535  https://www.royalroad.com/fiction/42226/foxs-t...        NaN     NaN
# 3853  https://www.royalroad.com/fiction/42226/foxs-t...        NaN     NaN
# 3854  https://www.royalroad.com/fiction/44543/fairyp...        NaN     NaN
# 268   https://www.wattpad.com/story/119064883-skin-d...        NaN     NaN
#
#       fandom_type                      fandom  fic_status  \
# 579           NaN                  batman,dcu         NaN
# 960           NaN                      bleach         NaN
# 611           NaN                      naruto         NaN
# 584           NaN                        bnha         NaN
# 514           NaN  bnha,katekyo_hitman_reborn         NaN
# ...           ...                         ...         ...
# 3852          NaN                    original         NaN
# 1535          NaN                         NaN         NaN
# 3853          NaN                         NaN         NaN
# 3854          NaN                         NaN         NaN
# 268           NaN                   teen_wolf         NaN
#
#                                                   title is_coffee fic_series  \
# 579   Gonna Be A Better One (A Thousand Miles To You...       NaN        NaN
# 960         On Life, On Death, On Everything In-Between       NaN        NaN
# 611   Dirt and Ashes, or: The One-and-a-Half Body Pr...       NaN        NaN
# 584                         (How To) Forgive and Forget       NaN        NaN
# 514   curiosity kills the cat (but satisfaction brin...       NaN        NaN
# ...                                                 ...       ...        ...
# 3852                                    The Perfect Run       NaN        NaN
# 1535                      Fox’s Tongue and Kirin’s Bone       NaN        NaN
# 3853                      Fox’s Tongue and Kirin’s Bone       NaN        NaN
# 3854                             #FairyPrincessProblems       NaN        NaN
# 268                  Skin Deep (Are the Secrets I Keep)       NaN        NaN
#
#            author length is_complete is_subbed is_backedup  is_bookmarked  \
# 579           NaN    NaN         NaN       NaN         NaN            NaN
# 960    cywscross,     51       False      True        TRUE            NaN
# 611           NaN    NaN         NaN       NaN         NaN            NaN
# 584           NaN    NaN         NaN       NaN         NaN            NaN
# 514           NaN    NaN         NaN       NaN         NaN            NaN
# ...           ...    ...         ...       ...         ...            ...
# 3852  Void Herald    NaN         NaN       NaN         NaN            NaN
# 1535  MuffinLance    NaN         NaN       NaN         NaN            NaN
# 3853  MuffinLance    NaN         NaN       NaN         NaN            NaN
# 3854    Miscellea    NaN         NaN       NaN         NaN            NaN
# 268    cywscross,     50         NaN       NaN         NaN            NaN
#
#       in_category                                           all_tags  \
# 579           NaN                                                NaN
# 960           NaN  well_written,.Time Travel,.BAMF,.Fix-It,.Prote...
# 611           NaN                                                NaN
# 584           NaN                                                NaN
# 514           NaN                                                NaN
# ...           ...                                                ...
# 3852          NaN                                                NaN
# 1535          NaN                                                NaN
# 3853          NaN                                                NaN
# 3854          NaN                                                NaN
# 268           NaN                                                NaN
#
#      current_chapter  fic_rating to_read_rating  \
# 579              NaN         NaN            NaN
# 960              NaN         3.0            NaN
# 611              NaN         NaN            NaN
# 584              NaN         NaN            NaN
# 514              NaN         NaN            NaN
# ...              ...         ...            ...
# 3852             NaN         NaN            NaN
# 1535             NaN         NaN            NaN
# 3853             NaN         NaN            NaN
# 3854             NaN         NaN            NaN
# 268                -         NaN              2
#
#                                     to_read_description  \
# 579   TimKon, In which Tim quits being Robin, Kon re...
# 960                                                 NaN
# 611   90k, Tozette's "In which Sakura carries half o...
# 584            76 collections, quirkless discrimination
# 514   33k, "Stuck in the body of a cat in another un...
# ...                                                 ...
# 3852                                                NaN
# 1535                                                NaN
# 3853                                                NaN
# 3854                                                NaN
# 268      selkie!Stiles, hurt/comfort, Steter, cywscross
#
#      is_finished_inputting_data ffn_date_updated_2-4-23 ffn_date_added
# 579                         NaN                     NaN            NaN
# 960                        True                     NaN            NaN
# 611                         NaN                     NaN            NaN
# 584                         NaN                     NaN            NaN
# 514                         NaN                     NaN            NaN
# ...                         ...                     ...            ...
# 3852                        NaN                     NaN            NaN
# 1535                        NaN                     NaN            NaN
# 3853                        NaN                     NaN            NaN
# 3854                        NaN                     NaN            NaN
# 268                        True                     NaN            NaN
#
# [1556 rows x 29 columns]

# %%
w2 = AO3.Work(13273611, session=ao3_session)

# %%
ao3_session = AO3.Session(os.environ['AO3_USERNAME'], os.environ['AO3_PASSWORD'])

# %%
import AO3

w1 = AO3.Work(18530821)

# %% [markdown]
# w1.bookmark
# w1.collect
# w1.comment
# w1.delete_bookmark
# w1.download
# w1.download_to_file
# w1.get
# w1.get_comments
# w1.get_images
# w1.leave_kudos
# w1.load_chapters
# w1.

# %%
w1.authenticity_token
w1.authors
w1.bookmarks
w1.categories
w1.chapters
w1.characters
w1.collections
w1.comments
w1.complete
w1.date_edited
w1.date_published
w1.date_updated
w1.end_notes
w1.expected_chapters
w1.fandoms
w1.hits
w1.is_subscribed
w1.kudos
w1.language
w1.loaded
w1.reload
w1.request
w1.set_session
w1.str_format
w1.subscribe
w1.unsubscribe
# Out:
#   Cell In[57], line 6
#     w1.
#        ^
# SyntaxError: invalid syntax

# %%
w1.str_format
# Out:
# <function AO3.works.Work.str_format(string)>

# %%
works.head()
# Out:
#          id     url_type   type  \
# 0  18530821  collections  works
# 1  39376755  collections  works
# 2  24311155  collections  works
# 3  42481512  collections  works
# 4  36456823  collections  works
#
#                                                  url from_collection  \
# 0  https://archiveofourown.org/collections/Whynot...   Whynotearlier
# 1  https://archiveofourown.org/collections/Whynot...   Whynotearlier
# 2  https://archiveofourown.org/collections/Whynot...   Whynotearlier
# 3  https://archiveofourown.org/collections/Whynot...   Whynotearlier
# 4  https://archiveofourown.org/collections/Whynot...   Whynotearlier
#
#   chapter_url      dateProcessed          dateAdded dateLastViewed  is_new
# 0         NaN  11-22-23 14:20:07  08-22-23 07:18:47           None    True
# 1         NaN  11-22-23 14:20:07  08-22-23 07:18:07           None    True
# 2         NaN  11-22-23 14:20:07  08-22-23 07:16:38           None    True
# 3         NaN  11-22-23 14:20:07  08-22-23 07:16:12           None    True
# 4         NaN  11-22-23 14:20:07  08-22-23 07:14:47           None    True

# %%
#session=AO3.Session(os.environ['AO3_USERNAME'], os.environ['AO3_PASSWORD'])):
def save_chapter(ind, df, session='hi'):
    """
    Modifies df in place to load info of fic at ind.
    """
    # work = AO3.Work(df.loc[ind, 'id'], session=session)
    work=w2

# %%
#session=AO3.Session(os.environ['AO3_USERNAME'], os.environ['AO3_PASSWORD'])):
def save_fic(ind, df, session=AO3.Session(os.environ['AO3_USERNAME'], os.environ['AO3_PASSWORD'])):
    """
    Modifies df in place to load info of fic at ind.
    """
    # work = AO3.Work(df.loc[ind, 'id'], session=session)
    work=w2

    # Get misc data
    df.loc[ind, 'api_url'] = work.url
    df.loc[ind, 'authenticity_token'] = work.authenticity_token
    df.loc[ind, 'start_notes'] = work.start_notes
    df.loc[ind, 'end_notes'] = work.end_notes
    df.loc[ind, 'is_subscribed'] = work.is_subscribed
    df.loc[ind, 'loaded'] = work.loaded
    df.loc[ind, 'oneshot'] = work.oneshot
    
    
    # Save text
    with open(f'ao3_text/{df.loc[ind, 'id']}_{datetime.now().strftime("%m-%d-%y")}') as outfile:
        json.dump(work.text, outfile)
            
    # Save chapters
    df.loc[ind, 'chapters'] = work.chapters

    # Save metadata

works2 = works.copy()
savefic(0, works2, 'hi')

# %%
w1.chapters[0].work
# Out:
# <Work [Flimflammer]>

# %%
parent_id
'authenticity_token',
 'end_notes',
 'id',
 'loaded',
 'number',
 'start_notes',
 'summary',
 'text',
 'title',
 'url',
 'words',

# %%
dir(w1.chapters[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_session',
#  '_soup',
#  '_work',
#  'authenticity_token',
#  'comment',
#  'end_notes',
#  'get',
#  'get_comments',
#  'get_images',
#  'id',
#  'loaded',
#  'number',
#  'reload',
#  'request',
#  'set_session',
#  'start_notes',
#  'summary',
#  'text',
#  'title',
#  'url',
#  'words',
#  'work']

# %%
w2.chapters[0].text
# Out:
# 'Alfred had hoped that the young master would hoard gold.\nBoth of his parents had hoarded it, after all; there was a large hoard of it already in the caves that made up their home, and the surrounding city-states still sent a tribute of it each year for lack of anyone telling them to stop. Providing him with sufficient amounts to keep him happy and healthy would have been relatively easy, and gold was gratifying simple to maintain.\nIt did have an unfortunate tendency to attract thieves, but now that the young master was nearing the end of adolescence, any who came would find themselves faced with a dragon more than prepared to defend the hoard. Even before that point, Alfred had prided himself on being a fairly efficient guard.\nGold would have been so simple.\nThese days, he was just hoping the young master would hoard anything at all. He was nearly out of adolescence; if he didn’t form and fulfill the hoarding urge soon, he never would, and dragons who didn’t maintain a healthy hoard had a distressing tendency to go mad in their latter years from lack of direction. Alfred had no desire to fail his charge that way.\nIt was just . . . Well, he wasn’t qualified for this. He had been hired all those many, many years ago to be a liaison between the dragon lords of the Gotham Mountains and the human inhabitants and to help maintain the caves they lived in. That he was well qualified for and had done.\nHe had just never thought that both the master and mistress would fly off to do battle for their territory and never return. He had never thought he alone would be left to raise their hatchling. \nAnd as hard as he tried, Alfred very much feared that he was not at all qualified for that.\n\xa0\nAlfred always fretted when the young master went out to patrol his territory. A forgivable failing all things considered.\nFor once, however, his alarm was not eased by the young master’s return. The young master was holding something gently in his claws, something he was peering down anxiously at -\n“Is that a child?” Alfred demanded.\nThe young master looked up in relief. “Oh, Alfred, good. I need your help. I don’t know what’s wrong with him. I breathed on him all the way here, but he’s still so quiet - “\nIt was a child. A small boy, to be exact. The young master had let go of him now, but he was still curled up in a small ball. There weren’t any visible injuries on him, but his clothes were wet with half dried blood.\nAlfred sighed and knelt next to him. “Hello,” he said gently. “I’ll just look you over, young sir, alright?”\nThe boy might have given a small nod, but he was shaking so hard that Alfred couldn’t be sure.\nHe checked him over quickly before standing back up and glaring at the young master. “Physically, he is fine, but as much good as dragon breath may do for ordinary injuries, I am afraid it does little for shock.”\n“But he’ll be alright?” the young master asked anxiously.\n“Eventually, yes.” Alfred’s glare intensified. “Now please tell me you didn’t kidnap the poor boy.”\nThe young master reared back in shock. “I found him! The bridge, the one over the chasm a few miles from here, got destroyed. It must have happened when his caravan was halfway across.” He nudged the boy gently with his nose. The boy leaned into the warmth. “He was the only one I could find that was still - “ He cut off, looking down guiltily at the boy.\nStill alive, Alfred finished for him. He was ashamed of his assumption. “Ah. Well done then, young master. Have you discovered what was responsible?”\nThe young master’s eyes darkened. A few sparks darted out of his nose. “A zucco. It was coming back just as I got there.” A low growl was building in his chest. “I took care of it.” He nosed the boy again. “It won’t bother you again.”\nWith the boy in shock, the warmth of a dragon would do him a world of good, but perhaps a blanket would be comforting as well. Alfred would be glad to give up one of his own for the time being. And some supper, of course. T ...

# %%
ke = ['authenticity_token',
 'authors',
 'bookmark',
 'bookmarks',
 'categories',
 'chapters',
 'characters',
 'collect',
 'collections',
 'comment',
 'comments',
 'complete',
 'date_edited',
 'date_published',
 'date_updated',
 'delete_bookmark',
 'download',
 'download_to_file',
 'end_notes',
 'expected_chapters',
 'fandoms',
 'get',
 'get_comments',
 'get_images',
 'hits',
 'id',
 'is_subscribed',
 'kudos',
 'language',
 'leave_kudos',
 'load_chapters',
 'loaded',
 'metadata',
 'nchapters',
 'oneshot',
 'rating',
 'relationships',
 'reload',
 'request',
 'restricted',
 'series',
 'set_session',
 'start_notes',
 'status',
 'str_format',
 'subscribe',
 'summary',
 'tags',
 'text',
 'title',
 'unsubscribe',
 'url',
 'warnings',
 'words']

# %%
w1.warnings
# Out:
# ['No Archive Warnings Apply']

# %%
dir(w1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bookmarkid',
#  '_session',
#  '_soup',
#  '_sub_id',
#  'authenticity_token',
#  'authors',
#  'bookmark',
#  'bookmarks',
#  'categories',
#  'chapters',
#  'characters',
#  'collect',
#  'collections',
#  'comment',
#  'comments',
#  'complete',
#  'date_edited',
#  'date_published',
#  'date_updated',
#  'delete_bookmark',
#  'download',
#  'download_to_file',
#  'end_notes',
#  'expected_chapters',
#  'fandoms',
#  'get',
#  'get_comments',
#  'get_images',
#  'hits',
#  'id',
#  'is_subscribed',
#  'kudos',
#  'language',
#  'leave_kudos',
#  'load_chapters',
#  'loaded',
#  'metadata',
#  'nchapters',
#  'oneshot',
#  'rating',
#  'relationships',
#  'reload',
#  'request',
#  'restricted',
#  'series',
#  'set_session',
#  'start_notes',
#  'status',
#  'str_format',
#  'subscribe',
#  'summary',
#  'tags',
#  'text',
#  'title',
#  'unsubscribe',
#  'url',
#  'warnings',
#  'words']
