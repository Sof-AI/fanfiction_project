# %% [markdown]
# # Merge s5 url+text types -> s6 total json (& clean other already-merged types)
# - **By:** Sofia Kobayashi
# - **Start Date:** 04/03/2024
# - **Description:** Need to merge fic + text files for data types:
#     - (1) fic
#     - (2) author
#     - (3) series
#     - (4) Clean: coffee, collections, look into, other

# %%
import pandas as pd
import re
import json
import numpy as np
from collections import Counter

import AO3

import os
from dotenv import load_dotenv
from pathlib import Path
env_path = Path(".") / ".env"
load_dotenv(dotenv_path=env_path)

pd.set_option('display.max_columns', None)

# %%
# Constants
LOCATION_ORDER = {'ao3': 1,
                  'ffn_net': 2,
                  'tum': 3,
                  'drm': 4,
                  'lvj': 5,
                  'fcb': 6,
                  'wat': 7,
                  'pdf': 9,
                  'oth': 100,
                 }

DTB_ORDER = {'coffee': 1,
            'read': 2,
            'cont_read': 3,
            'to_read': 4}

# %%
# Helper Functions
def df_to_dict(df):
    
    # Make sure there are NOT empty dfs
    if len(df) == 0:
        raise Exception("ERROR: given empty dict in df_to_dict()")
   
    
    # Get dict, remove NaN's & de-dup lists
    cols = df.to_dict('list')

    for key in cols:
        cols[key] = list(set([ele for ele in cols[key] if not pd.isna(ele)]))

    return cols

# %% [markdown]
# ## (1) Re-merge s5 fic text
# - **Problem:** The initial s4 -> s5 merge was NOT THOUROUGH, many duplicates still exist
# - **Thus:** Will add a stripped title col called 'title_str', merge on that
# - **Desired Result:** s5 fic text JSON with no duplicates

# %% [markdown]
# ### Add title_str col & make s5 fic text -> JSON
# - Matching on titles were difficult bc sometimes different apostrophes or spacing or parenthesis, so strip all that to make title_str

# %%
# Read in relevant files
with open("clean_data_5/fic_url.json", "r") as infile:
    fic_url = json.load(infile)

fic_text_df = pd.read_csv("clean_data_5/fic_text.csv", index_col=0, encoding="utf-8-sig")
fic_text_df['title'] = fic_text_df['title'].astype(str)

# %%
# Function to make title string
def strip_title(title):
    clean_str = ''
    for char in title:
        if char.isalnum():
            clean_str += char
    return clean_str.lower().replace(" ", "")

# Testing
strip_title("he's the fun uncle. you know, the immortal one.")
# Out:
# 'hesthefununcleyouknowtheimmortalone'

# %%
# Code to add cleaned title string col
fic_text_df['title_str'] = fic_text_df['title'].apply(strip_title)

# %% [markdown]
# ### Remerge s5 fic text on the new title_str
# - Merges on title_str

# %%
def convert_to_dict_s5_text(df):
    cols = df.to_dict('list')

    for key in cols:
        new_row = []

        for val in cols[key]:
            # If list-wrapped string, break up values
            if isinstance(val, str) and len(val) > 0 and val[0] == '[':
                try: 
                    clean_val = val.replace("['", '["').replace("']", '"]').replace("', '", '", "').replace("','", '","')
                    val = json.loads(clean_val)
                
                    for ele in val: 
                        new_row.append(ele)
                except:
                    new_row.append("."+val)
            # If stringified boolean
            elif isinstance(val, str) and val.lower() == "false":
                new_row.append(False) 
            elif isinstance(val, str) and val.lower() == "true":
                new_row.append(True) 
            else:
                new_row.append(val)

        # De-dup & drop all nulls
        new_row = list(set([ele for ele in new_row if not pd.isna(ele)]))
        cols[key] = new_row
        
    return cols

# %%
# Function to merge fics
def merge_fic(parent_df, title_str):
    df = parent_df[parent_df['title_str'] == title_str]
    
    # Make sure there are NOT empty dfs
    if len(df) == 0:
        raise Exception("ERROR: given empty dict in df_to_dict()")
   
    # Get dict, remove NaN's & de-dup lists
    cols = convert_to_dict_s5_text(df)

    # Sort & clean various attributes
    sorted_sources = sorted(cols['smk_sources'], key = lambda source: float(source.split('_')[0][1:]))
    clean_authors = list(set([author.replace(",", "") for author in cols['author']]))
    sorted_versions = sorted(cols['version_nums'])
    clean_locs = [loc for loc in cols["locations"] if loc!= '???']
    sorted_locations = sorted(clean_locs, key=lambda loc: LOCATION_ORDER[loc])
    
    clean_dtbs = set()
    for dtb_str in cols['dtb_types']:
        new_dtbs = dtb_str.split(',')
        for dtb in new_dtbs:
            clean_dtbs.add(dtb.strip())
    clean_dtbs = list(clean_dtbs)
    sorted_dtbs = sorted(clean_dtbs, key=lambda dtb: DTB_ORDER[dtb])

    clean_tags = set()
    for tag_str in cols['all_tags']:
        new_tags = tag_str.split(',')
        for tag in new_tags:
            clean_tags.add(tag.strip())
    sorted_tags = sorted(list(clean_tags))
    
    avg_rating = None if len(cols['all_ratings']) == 0 else round(sum(cols['all_ratings'])/len(cols['all_ratings']), 2)
                
    return {'num_appeared': len(df),
            'primary_versions': "" if len(sorted_versions) == 0 else sorted_versions[0],
            'version_num': sorted_versions,
            'primary_source': "" if len(sorted_sources) == 0 else sorted_sources[0],
             'smk_source': sorted_sources,
            'primary_dtb': "" if len(sorted_dtbs) == 0 else sorted_dtbs[0],
             'dtb_type': sorted_dtbs,
            'primary_loction': "" if len(sorted_locations) == 0 else sorted_locations[0],
             'location': sorted_locations,
            'primary_url': "" if len(cols['primary_link']) == 0 else cols['primary_link'][0],
             'url': sorted(cols['all_links']),
             'categories': cols['categories'],
             'is_bold': None if len(cols["is_bold"]) == 0 else any(cols["is_bold"]), 
             'fandom': cols['fandom'],
             'fic_status': None, # this column is entirely empty
             'title': "" if len(cols['title']) == 0 else cols['title'][0],
             'title_str': "" if len(cols['title']) == 0 else cols['title'][0],
             'is_coffee': None if len(cols["is_coffee"]) == 0 else any(cols["is_coffee"]), 
             'fic_series': cols['fic_series'],
             'author': clean_authors,
             'length': None if len(cols["length"]) == 0 else max(cols["length"]),
             'is_complete': None if len(cols["is_complete"]) == 0 else any(cols["is_complete"]), 
             'is_subbed': None if len(cols["is_subbed"]) == 0 else any(cols["is_subbed"]), 
             'is_backedup': None if len(cols["is_backedup"]) == 0 else any(cols["is_backedup"]), 
             'is_bookmarked': None if len(cols["is_bookmarked"]) == 0 else any(cols["is_bookmarked"]), 
             'in_category': None, # this column is entirely empty
             'all_tags': sorted_tags,
             'current_chapter': "" if len(cols["current_chapter"]) == 0 else max(cols["current_chapter"]),
             'fic_rating': avg_rating, 
             'early_ratings': cols['early_ratings'],
             'to_read_description': cols['tr_descriptions'],
             'is_finished_inputting_data': None if len(cols["is_complete"]) == 0 else any(cols["is_complete"]), 
           }

# Testing
# merge_fic(fic_text_df, 'allhallowsevenewyork')

# %%
# Code to merge s5 fic text
title_strs = fic_text_df.title_str.drop_duplicates().sort_values().to_list()
merged_rows = []

for title_str in title_strs:
    new_dict = merge_fic(fic_text_df, title_str)
    merged_rows.append(new_dict)

merged_df = pd.DataFrame(merged_rows)

# %% [markdown]
# ### Clean s5 fic text fandoms

# %%
with open('reference_info/fandom_aliases.json', 'r') as infile:
    FANDOM_NAMES = json.load(infile)

# %%
# Cleaned fic fandoms
# Function to uncompact (split, dedup, order) fandom strings
def split_and_sort_fandoms(dict):
    for fic in dict:
        clean_fandoms = set()
        for fandom_str in fic['fandom']:
            for fandom in fandom_str.split(","):
                if fandom != "":
                    clean_fandoms.add(fandom.strip())
                
        fandom_list = list(clean_fandoms)
        fic['fandom'] = sorted(fandom_list)

# Clean dict
split_and_sort_fandoms(merged_rows)

# Check for compacted fandoms
for fic in merged_rows:
    for fandom_str in fic['fandom']:
        if ',' in fandom_str:
            print(fic['fandom'])

# Printing none means it workeda

# %%
FANDOM_CONVERSION_2 = {
    "1/2_prince": "1/2 Wangzi | 1/2 Prince",
    "2ha": "二哈和他的白猫师尊 - 肉包不吃肉 | The Husky and His White Cat Shizun - Meatbun Doesn't Eat Meat",
    "arrow": "Arrow (TV 2012)",
    "artemis_fowl": "Artemis Fowl - Eoin Colfer",
    "assassins_creed": "Assassin's Creed - All Media Types",
    "ateez_band": "ATEEZ (Band)",
    "atla": "Avatar: The Last Airbender",
    "attack_on_titan": "Shingeki no Kyojin | Attack on Titan",
    "avatar": "Avatar (Cameron Movies)",
    "avengers": "Avengers (Marvel) - All Media Types",
    "batman": "Batman - All Media Types",
    "big_hero_6": "Big Hero 6 (2014)",
    "black_butler": "Kuroshitsuji | Black Butler",
    "black_panther": "Black Panther (2018)",
    "bleach": "Bleach",
    "bnha": "僕のヒーローアカデミア | Boku no Hero Academia | My Hero Academia",
    "books_of_the_raksura": "Books of the Raksura - Martha Wells",
    "brooklyn_99": "brooklyn_99",
    "bts": "방탄소년단 | Bangtan Boys | BTS",
    "captain_america": "Captain America - All Media Types",
    "captive_prince": "Captive Prince - C. S. Pacat",
    "castlevania": "Castlevania (Cartoon 2017-2021)",
    "chronicles_of_narnia": "Chronicles of Narnia - C. S. Lewis",
    "code_geass": "Code Geass",
    "criminal_minds": "Criminal Minds (US TV)",
    "damien": "Damien (TV)",
    "danny_phantom": "Danny Phantom",
    "daredevil": "Daredevil (TV)",
    "dark_angel": "Dark Angel (TV)",
    "dcu": "DCU",
    "deadpool": "Deadpool - All Media Types",
    "death_note": "Death Note (Anime & Manga)",
    "descendants": "Descendants (Disney Movies)",
    "detroit_become_human": "Detroit: Become Human (Video Game)",
    "downton_abbey": "Downton Abbey",
    "eyeshield_21": "Eyeshield 21",
    "fairy_tail": "Fairy Tail",
    "fantastic_four": "Fantastic Four",
    "fast&furious": "Fast & Furious (Movies)",
    "fbawtft": "Fantastic Beasts and Where to Find Them (Movies)",
    "final_fantasy_vii": "Final Fantasy VII",
    "final_fantasy_viii": "Final Fantasy VIII",
    "final_fantasy_xv": "Final Fantasy XV",
    "folklore": "Folklore",
    "frozen": "Frozen (Disney Movies)",
    "fullmetal_alchemist": "Fullmetal Alchemist - All Media Types",
    "game_of_thrones": "A Song of Ice and Fire & Related Fandoms",
    "good_omens": "Good Omens (TV)",
    "gotham": "Gotham (TV)",
    "gravity_falls": "Gravity Falls",
    "guardians_of_the_galaxy": "Guardians of the Galaxy (Movies)",
    "gundam_wing_ac": "Gundam Wing",
    "hamilton": "Hamilton - Miranda",
    "hannibal": "Hannibal (TV)",
    "harry_potter": "Harry Potter - Fandom",
    "hells_kitchen": "Hell's Kitchen",
    "highschool_of_the_dead": "Gakuen Mokushiroku | Highschool of the Dead",
    "httyd": "How to Train Your Dragon (Movies)",
    "hunger_games": "Hunger Games Series - All Media Types",
    "iron_man": "Iron Man (Movies)",
    "james_bond": "James Bond (Movies)",
    "john_wick": "John Wick (Movies)",
    "joy_of_life": "庆余年 | Joy of Life (TV)",
    "jurassic_park": "Jurassic Park - All Media Types",
    "justice_league": "Justice League - All Media Types",
    "k_anime": "K (Anime)",
    "katekyo_hitman_reborn": "Katekyou Hitman Reborn!",
    "kingsman": "Kingsman (Movies)",
    "kung_fu_panda": "Kung Fu Panda (Movies)",
    "kuroko_no_basuke": "Kuroko no Basuke | Kuroko's Basketball",
    "left4dead": "Left 4 Dead (Video Games)",
    "legend_of_korra": "Avatar: Legend of Korra",
    "leverage": "Leverage",
    "loki": "Loki (TV 2021)",
    "lord_of_the_rings": "The Lord of the Rings - All Media Types",
    "lucifer": "Lucifer (TV)",
    "magi_lom": "Magi: The Labyrinth of Magic",
    "magnus_files": "The Magnus Archives (Podcast)",
    "mcu": "MCU",
    "mdzs": "魔道祖师 - 墨香铜臭 | Módào Zǔshī - Mòxiāng Tóngxiù",
    "megamind": "Megamind (2010)",
    "men_in_black": "men_in_black",
    "merlin": "Merlin (TV)",
    "minecraft": "Minecraft (Video Game)",
    "miraculous_ladybug": "Miraculous Ladybug",
    "mob_psycho": "モブサイコ100 | Mob Psycho 100",
    "monster_hunter": "Monster Hunter (Video Games)",
    "moon_knight": "Moon Knight (TV 2022)",
    "multiple_fandoms": "multiple_fandoms",
    "my_next_life_as_a_villainess": "乙女ゲームの破滅フラグしかない悪役令嬢に転生してしまった… - 山口悟 | My Next Life as a Villainess - Yamaguchi Satoru (Light Novels)",
    "naruto": "Naruto",
    "ncis": "NCIS",
    "nirvana_in_fire": "nirvana_in_fire",
    "none_unsorted": "none_unsorted",
    "once_upon_a_time": "Once Upon a Time (TV)",
    "one_piece": "One Piece",
    "one_punch_man": "ワンパンマン | One-Punch Man",
    "original_work": "Original Work",
    "ouran_hshc": "Ouran High School Host Club - All Media Types",
    "pacific_rim": "Pacific Rim (Movies)",
    "percy_jackson_olympians": "Percy Jackson and the Olympians & Related Fandoms - All Media Types",
    "person_of_interest": "Person of Interest (TV)",
    "phineas_and_ferb": "Phineas and Ferb",
    "pkmn_sword&shield": "Pocket Monsters: Sword & Shield | Pokemon Sword & Shield Versions",
    "pokemon": "Pocket Monsters | Pokemon (Anime)",
    "prince_of_tennis": "Tennis no Oujisama | Prince of Tennis",
    "reincarnated_as_a_sword": "転生したら剣でした - 棚架ユウ | Tensei Shitara Ken Deshita | Reincarnated as a Sword - Tanaka YuuNavigation and Actions",
    "rise_of_the_guardians": "Rise of the Guardians (2012)",
    "riverdale": "riverdale",
    "rwby": "RWBY",
    "sherlock": "Sherlock (TV)",
    "six_of_crows": "Six of Crows Series - Leigh Bardugo",
    "smallville": "Smallville",
    "solo_levelling": "나 혼자만 레벨업 | Solo Leveling (Webcomic)",
    "soul_eater": "Soul Eater (Anime & Manga)",
    "spiderman": "Spider-Man - All Media Types",
    "star_wars": "Star Wars - All Media Types",
    "star_wars_cw": "Star Wars: Clone Wars (2003) - All Media Types",
    "stargate": "Stargate - All Media Types",
    "stargate_atlantis": "Stargate Atlantis",
    "stranger_things": "Stranger Things (TV 2016)",
    "suicide_squad": "Suicide Squad (Movies 2016 2021)",
    "supernatural": "Supernatural",
    "svsss": "人渣反派自救系统 - 墨香铜臭 | The Scum Villain's Self-Saving System - Mòxiāng Tóngxiù",
    "sword_art_online": "Sword Art Online (Anime & Manga)",
    "tangled": "Tangled (2010)",
    "teen_wolf": "Teen Wolf (TV)",
    "temeraire": "Temeraire - Naomi Novik",
    "the_100": "The 100 (TV)",
    "the_arrow": "Arrow (TV 2012)",
    "the_croods": "The Croods (Movies)",
    "the_flash": "The Flash (Comics)",
    "the_hobbit": "The Hobbit - All Media Types",
    "the_kings_avatar": "全职高手 | The King's Avatar (Cartoon)",
    "the_last_of_us": "The Last of Us (Video Games)",
    "the_song_of_achillles": "The Song of Achilles - Madeline Miller",
    "the_witcher": "The Witcher (TV)",
    "thor": "Thor - All Media Types",
    "tiger&bunny": "Tiger & Bunny",
    "tokyo_ghoul": "Tokyo Ghoul",
    "torchwood": "Torchwood",
    "transformers": "Transformers - All Media Types",
    "travelers": "Travelers (TV)",
    "twilight": "Twilight Series - All Media Types",
    "umbrella_academy": "The Umbrella Academy (TV)",
    "vampire_hunter_d": "Vampire Hunter D (Anime & Manga)",
    "venom": "Venom (Marvel Movies)",
    "voltron": "Voltron: Legendary Defender",
    "wicked": "Wicked - All Media Types",
    "winx_club": "Winx Club",
    "xmen": "X-Men - All Media Types",
    "yona_of_the_dawn": "Akatsuki no Yona | Yona of the Dawn",
    "young_hercules": "Young Hercules",
    "young_justice": "Young Justice - All Media Types",
    "yuuri_on_ice": "Yuri!!! on Ice (Anime)",
    "zootopia": "Zootopia (2016)",
}

# %%
# Function & code to convert my fandoms to ao3 fandoms
def convert_my_fandoms_to_ao3_fandoms(dict):
    for fic in dict:
        clean_fandoms = []
        for fandom in fic['fandom']:
            if fandom in FANDOM_NAMES:
                fandom = FANDOM_CONVERSION_2[fandom]
            clean_fandoms.append(fandom)
        fic['fandom'] = sorted(clean_fandoms)

convert_my_fandoms_to_ao3_fandoms(merged_rows)

# %%
s2 = set()
for fic in merged_rows:
  for fandom in fic['fandom']:
      if fandom == 'avatar':
          print(fic)
      if fandom in FANDOM_NAMES and fandom not in FANDOM_CONVERSION_2:
          s2.add(fandom)

sorted(list(s2))
# Out:
# []

# %%
# Write to JSON
with open('clean_data_5/fic_text.json', 'w') as outfile:
    json.dump(merged_rows, outfile)

# %% [markdown]
# ## (2) s5 fic text+url merging
# - **Problem:** There's many duplicates across s4 fic url & s4 fic text, want to merge them
# - **Thus:** Will merge them
# - **Desired Result:** JSON with each dict only referencing one fic

# %%
# Constants
LOCATION_ORDER = {'ao3': 1,
                  'ffn_net': 2,
                  'tum': 3,
                  'drm': 4,
                  'lvj': 5,
                  'fcb': 6,
                  'wat': 7,
                  'pdf': 9,
                  'oth': 100,
                 }

DTB_ORDER = {'coffee': 1,
            'read': 2,
            'cont_read': 3,
            'to_read': 4}

# %%
# Load in relevant files
with open('clean_data_5/fic_text.json', 'r') as infile:
    text_unmerged = json.load(infile)

with open('clean_data_5/fic_url.json', 'r') as infile:
    url_unmerged = json.load(infile)

# Sort dicts by title_str
text_unmerged = sorted(text_unmerged, key=lambda fic: fic['title_str'])
url_unmerged = sorted(url_unmerged, key=lambda fic: fic['title_str'])

# %% [markdown]
# ### Clean s5 fic text & url data
# - Clean duplicates
# - Standardizing key names

# %%
# (already done) Add title_str column to both s5 fic url & text
# for fic in url_unmerged: 
#     fic['title_str'] = strip_title(fic['title'])

# for fic in text_unmerged: 
#     fic['title_str'] = strip_title(fic['title'])

# %%
# Code to switch keys in dicts (to standardize key names of shared data kinds)
swaps = [{'original': 'primary_versions', 'new': 'primary_version'},
        {'original': 'location', 'new': 'locations'},
        {'original': 'smk_source', 'new': 'smk_sources'},
        {'original': 'dtb_type', 'new': 'dtb_types'},
        {'original': 'primary_loction', 'new': 'primary_location'},
        {'original': 'primary_link', 'new': 'primary_url'},
        {'original': 'all_links', 'new': 'all_urls'},
        {'original': 'url', 'new': 'all_urls'},
        {'original': 'version_num', 'new': 'version_nums'},]


for swap in swaps:
    ORIGINAL = swap['original']
    NEW = swap['new']

    for fic in url_unmerged:
        if ORIGINAL in fic:
            fic[NEW] = fic[ORIGINAL]
            del fic[ORIGINAL]
    
    
    for fic in text_unmerged:
        if ORIGINAL in fic:
            fic[NEW] = fic[ORIGINAL]
            del fic[ORIGINAL]

# %%
# Check - Keys only in url dict
url_only_keys = []
for k1 in url_unmerged[0]:
    if k1 not in text_unmerged[0]:
        print(k1)
        url_only_keys.append(k1)

# Should print a few key names (these are not in text dict)
# Out:
# work_type
# fic_id
# all_ratings
# fandom_type
# ffn_date_added
# ffn_date_updated_2-4-23
# readability_status
# to_read_rating
# error

# %%
# Check - Keys only in text dict 
text_only_keys = []
for k1 in text_unmerged[0]:
    if k1 not in url_unmerged[0]:
        print(k1)
        text_only_keys.append(k1)

# Should print a few key names (these are not in url dict)
# Out:
# length
# early_ratings

# %% [markdown]
# ### Clean s5 fic text & url data
# - combining ao3/ao3 and ao3/ffn duplicates

# %%
# title_str with >1 fic (all happened to be in url_unmerged, none in text_unmerged)
# Doubles filled when running "Code to merge all s5 fic text + url", which is intensive, so saved here
doubles = ['achildavenged', 'adropofpoison', 'anacttoooftenneglected', 'babyitscoldoutside', 'bestlaidplans', 'byanyothername', 
            'catalysis', 'dusktodawn', 'everythingcanchange', 'familybonds', 'foolmeonce', 'foradventureandchaos', 
            'gaslightingthenecronomicon', 
            'guillotine', 'heavensgarden', 'herphantom', 'iholdwiththosewhofavorfire', 'imaginaryfriend', 'intertwined', 'learningtofly', 
            'lostboys', 'loyalty', 'nest', 'practicemakesperfect', 'retrograde', 'rumorhasit', 'scorched', 'seagullsandbeetles',
            'solstice', 'somewheretobelong', 'spadesonscreen', 'standards', 'tenyearsdifference', 'thegamehasonlyjustbegun', 
            'thelivesworthsaving', 'thenightthehouseofcardswasbuilt', 'tobuildahome', 'unexpected', 'wanderer'
          ]

# %%
# Get formatted doubles
diff_doubles = []
ind_doubles = []
for ts in doubles: 
    locs = []
    d = []
    for i, fic in enumerate(url_unmerged):
        if fic['title_str'] == ts:
            # locs.append(fic['primary_location'])
            d.append(i)
    # if locs[0] == locs[1]:
    diff_doubles.append(ts)
    ind_doubles.append(d)

pairs = list(zip(diff_doubles, ind_doubles))

# Print pairs to manually determine which are duplicates
for pair in pairs:
    print(pair[0])
    for i in pair[1]:
        print(f"TITLE ({i}): {url_unmerged[i]['title']}")
        print(f"AUTHOR: {url_unmerged[i]['author']}")
        print(f"FANDOM: {url_unmerged[i]['fandom']}")
        print()
    print('-------\n')
# Out:
# achildavenged
# TITLE (46): A Child Avenged
# AUTHOR: ['pandaswearglasses']
# FANDOM: ['Avengers (Marvel) - All Media Types', 'Harry Potter - Fandom']
#
# TITLE (47): A Child Avenged
# AUTHOR: ['PandasWearGlasses']
# FANDOM: ['Harry Potter - Fandom']
#
# -------
#
# adropofpoison
# TITLE (63): A Drop of Poison
# AUTHOR: ['Androgyninja']
# FANDOM: ['Naruto']
#
# TITLE (64): A Drop of Poison
# AUTHOR: ['Angel of Snapdragons']
# FANDOM: ['Naruto']
#
# -------
#
# anacttoooftenneglected
# TITLE (128): An Act Too Often Neglected
# AUTHOR: ['thehoyden']
# FANDOM: ['X-Men - All Media Types']
#
# TITLE (129): an act too often neglected
# AUTHOR: ['Ariaste']
# FANDOM: ['陈情令 | The Untamed (TV)', '魔道祖师 - 墨香铜臭 | Módào Zǔshī - Mòxiāng Tóngxiù']
#
# -------
#
# babyitscoldoutside
# TITLE (253): Baby, It's Cold Outside
# AUTHOR: ['Fweeble']
# FANDOM: ['Tokyo Ghoul']
#
# TITLE (254): Baby It's Cold Outside
# AUTHOR: ['Defective_Avian']
# FANDOM: ['Batman - All Media Types', 'DCU (Comics)']
#
# -------
#
# bestlaidplans
# TITLE (285): Best Laid Plans
# AUTHOR: ['esama']
# FANDOM: ['Harry Potter - Fandom']
#
# TITLE (286): Best Laid Plans
# AUTHOR: ['SadinaSaphritetearsontherocks']
# FANDOM: ['Pocket Monsters: Sword & Shield | Pokemon Sword & Shield Versions']
#
# -------
#
# byanyothername
# TITLE (372): By Any Other Name
# AUTHOR: ['astolat']
# FANDOM: ['Wiedźmin | The Witcher (Video Game)']
#
# TITLE (373): By Any Other Name
# AUTHOR: ['ShanaStoryteller']
# FANDOM: ['陈情令 | The Untamed (TV)', '魔道祖师 - 墨香铜臭 | Módào Zǔshī - Mòxiāng Tóngxiù']
#
# -------
#
# catalysis
# TITLE (398): Catalysis
# AUTHOR: ['aventriailuxia', 'aventria iluxia']
# FANDOM: ['Fullmetal Alchemist', 'Fullmetal Alchemist - All Media Types']
#
# TITLE (399): Catalysis
# AUTHOR: ['Teh Twinnesses Presents']
# FANDOM: ['Fullmetal Alchemist - All Media Types']
#
# -------
#
# dusktodawn
# TITLE (586): Dusk to Dawn
# AUTHOR: ['Reighost', 'Reighost']
# FANDOM: ['Harry Potter - Fandom', 'Harry Potter - J. K. Rowling', 'Katekyou Hitman Reborn!', 'Katekyou Hitman Reborn!']
#
# TITLE (587): Dusk To Dawn
# AUTHOR: ['reighost']
# FANDOM: ['Harry Potter - Fandom']
#
# -------
#
# everythingcanchange
# TITLE (616): Everything Can Change
# AUTHOR: ['Seito']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# TITLE (617): Everything Can Change
# AUTHOR: ['Seito']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# -------
#
# familybonds
# TITLE (645): Family Bonds
# AUTHOR: ['xXDesertRoseXx']
# FANDOM: ['Harry Potter - Fandom']
#
# TITLE (646): Family Bonds
# AUTHOR: ['xXDesertRoseXx']
# FANDOM: ['Harry Potter - Fandom']
#
# -------
#
# foolmeonce
# TITLE (702): Fool Me Once
# AUTHOR: ['CaffeinatedFlumadiddle']
# FANDOM: ['Merlin (TV)']
#
# TITLE (703): Fool Me Once
# AUTHOR: ['Pip (Moirail)']
# FANDOM: ['陈情令 | The Untamed (TV)', '魔道祖师 - 墨香铜臭 | Módào Zǔshī - Mòxiāng Tóngxiù']
#
# -------
#
# foradventureandchaos
# TITLE (706): For Adventure and Chaos
# AUTHOR: ['Seito']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# TITLE (707): For Adventure and Chaos
# AUTHOR: ['Seito']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# -------
#
# gaslightingthenecronomicon
# TITLE (763): Gaslighting the Necronomicon
# AUTHOR: ['Ourliazo']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# TITLE (764): Gaslighting the Necronomicon
# AUTHOR: ['Ourliazo']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# -------
#
# guillotine
# TITLE (831): Guillotine
# AUTHOR: ['PsychoLimbo']
# FANDOM: ['僕のヒーローアカデミア | Boku no Hero Academia | My Hero Academia']
#
# TITLE (832): Guillotine
# AUTHOR: ['milkofthepoppy']
# FANDOM: ['僕のヒーローアカデミア | Boku no Hero Academia | My Hero Academia']
#
# -------
#
# heavensgarden
# TITLE (857): Heaven's Garden
# AUTHOR: ['RenegadeWarrior', 'RenegadeWarrior']
# FANDOM: ['Katekyou Hitman Reborn!', 'Katekyou Hitman Reborn!']
#
# TITLE (858): Heaven's Garden
# AUTHOR: ['RenegadeWarrior']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# -------
#
# herphantom
# TITLE (880): Her Phantom
# AUTHOR: ['GemNika', 'GemNika']
# FANDOM: ['Fairy Tail', 'Fairy Tail']
#
# TITLE (881): Her Phantom
# AUTHOR: ['GemNika']
# FANDOM: ['Fairy Tail']
#
# -------
#
# iholdwiththosewhofavorfire
# TITLE (987): I hold with those who favor fire
# AUTHOR: ['kaydeefalls']
# FANDOM: ['Folklore']
#
# TITLE (988): I Hold With Those Who Favor Fire
# AUTHOR: ['northpeachwolfrainrules']
# FANDOM: ['僕のヒーローアカデミア | Boku no Hero Academia | My Hero Academia']
#
# -------
#
# imaginaryfriend
# TITLE (1001): Imaginary Friend
# AUTHOR: ['metamorcy', 'metamorcy']
# FANDOM: ['Katekyou Hitman Reborn!', 'Katekyou Hitman Reborn!']
#
# TITLE (1002): Imaginary Friend
# AUTHOR: ['Metamorcy']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# -------
#
# intertwined
# TITLE (1036): Intertwined
# AUTHOR: ['', 'BloodyWar2411']
# FANDOM: ['Fullmetal Alchemist - All Media Types', 'Fullmetal Alchemist - All Media Types']
#
# TITLE (1037): Intertwined
# AUTHOR: ['cywscross']
# FANDOM: ['Naruto']
#
# TITLE (1038): Intertwined
# AUTHOR: ['BloodyWar2411']
# FANDOM: ['Fullmetal Alchemist - All Media Types']
#
# -------
#
# learningtofly
# TITLE (1150): Learning to Fly
# AUTHOR: ['astolat']
# FANDOM: ['Thor - All Media Types']
#
# TITLE (1151): learning to fly
# AUTHOR: ['a_bo28']
# FANDOM: ['Thor - All Media Types']
#
# -------
#
# lostboys
# TITLE (1212): Lost Boys
# AUTHOR: ['thisisnotwhoyouthink']
# FANDOM: ['Thor - All Media Types']
#
# TITLE (1213): Lost Boys
# AUTHOR: ['Glacis']
# FANDOM: ['Bleach']
#
# -------
#
# loyalty
# TITLE (1229): Loyalty
# AUTHOR: ['WhisperingDarkness']
# FANDOM: ['Harry Potter - Fandom', 'Naruto']
#
# TITLE (1230): Loyalty
# AUTHOR: ['Lartharion']
# FANDOM: ["人渣反派自救系统 - 墨香铜臭 | The Scum Villain's Self-Saving System - Mòxiāng Tóngxiù"]
#
# TITLE (1231): Loyalty
# AUTHOR: ['Whispering Darkness']
# FANDOM: ['Harry Potter - Fandom']
#
# -------
#
# nest
# TITLE (1335): Nest
# AUTHOR: ['Ourliazo']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# TITLE (1336): Nest
# AUTHOR: ['Ourliazo']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# -------
#
# practicemakesperfect
# TITLE (1538): Practice Makes Perfect
# AUTHOR: ['MarbleAide']
# FANDOM: ['DCU (Comics)', 'Teen Titans (Comics)', 'Young Justice (Cartoon)']
#
# TITLE (1539): Practice Makes Perfect
# AUTHOR: ['platonic_boner']
# FANDOM: ['Merlin (TV)']
#
# -------
#
# retrograde
# TITLE (1629): Retrograde
# AUTHOR: ['agent37 (kaivevo)']
# FANDOM: ['Batman - All Media Types', 'DCU (Comics)']
#
# TITLE (1630): retrograde
# AUTHOR: ['sixthmoon (seventhstar)']
# FANDOM: ["人渣反派自救系统 - 墨香铜臭 | The Scum Villain's Self-Saving System - Mòxiāng Tóngxiù"]
#
# -------
#
# rumorhasit
# TITLE (1658): Rumor Has It
# AUTHOR: ['']
# FANDOM: ['Code Geass']
#
# TITLE (1659): rumor has it
# AUTHOR: ['suzukiblu']
# FANDOM: ['Avatar: The Last Airbender']
#
# -------
#
# scorched
# TITLE (1701): Scorched
# AUTHOR: ['RenegadeWarrior']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# TITLE (1702): Scorched
# AUTHOR: ['RenegadeWarrior']
# FANDOM: ['Katekyou Hitman Reborn!']
#
# -------
#
# seagullsandbeetles
# TITLE (1708): Seagulls and Beetles
# AUTHOR: ['Stormy1x2', 'stormy1x2']
# FANDOM: ['One Piece', 'One Piece']
#
# TITLE (1709): Seagulls and Beetles
# AUTHOR: ['Stormy1x2']
# FANDOM: ['One Piece']
#
# -------
#
# solstice
# TITLE (1784): Solstice
# AUTHOR: ['ShanaStoryteller']
# FANDOM: ['Naruto']
#
# TITLE (1785): solstice
# AUTHOR: ['tagteamme']
# FANDOM: ['魔道祖师 - 墨香铜臭 | Módào Zǔshī - Mòxiāng Tóngxiù', '魔道祖师 | Módào Zǔshī (Cartoon)']
#
# -------
#
# somewheretobelong
# TITLE (1801): somewhere to belong
# AUTHOR: ['KouriArashi']
# FANDOM: ['陈情令 | The Untamed (TV)']
#
# TITLE (1802): Somewhere To Belong
# AUTHOR: ['', 'Pizza yum']
# FANDOM: ['One Piece']
#
# -------
#
# spadesonscreen
# TITLE (1813): Spades On-Screen
# AUTHOR: ['Stormy1x2']
# FANDOM: ['One Piece']
#
# TITLE (1814): Spades On Screen
# AUTHOR: ['Stormy1x2']
# FANDOM: ['One Piece']
#
# -------
#
# standards
# TITLE (1832): Standards
# AUTHOR: ['taizi']
# FANDOM: ['One Piece']
#
# TITLE (1833): Standards
# AUTHOR: ['Taisi']
# FANDOM: ['One Piece']
#
# -------
#
# tenyearsdifference
# TITLE (1936): Ten Years Difference
# AUTHOR: ['Stormy1x2', 'stormy1x2']
# FANDOM: ['One Piece', 'One Piece']
#
# TITLE (1937): Ten Years Difference
# AUTHOR: ['Stormy1x2']
# FANDOM: ['One Piece']
#
# -------
#
# thegamehasonlyjustbegun
# TITLE (2025): The Game Has Only Just Begun
# AUTHOR: ['Seito']
# FANDOM: ['Yuri!!! on Ice (Anime)']
#
# TITLE (2026): The Game Has Only Just Begun
# AUTHOR: ['Seito']
# FANDOM: ['Yuri!!! on Ice (Anime)']
#
# -------
#
# thelivesworthsaving
# TITLE (2067): The Lives Worth Saving
# AUTHOR: ['cywsphyre', 'cywsaphyre NikkiCross']
# FANDOM: ['Naruto', 'Naruto']
#
# TITLE (2068): The Lives Worth Saving
# AUTHOR: ['cywsaphyre']
# FANDOM: ['Naruto']
#
# -------
#
# thenightthehouseofcardswasbuilt
# TITLE (2096): The Night the House of Cards was Built
# AUTHOR: ['drakensis']
# FANDOM: ['Naruto']
#
# TITLE (2097): The Night The House of Cards Was Built
# AUTHOR: ['drakensis']
# FANDOM: ['Naruto']
#
# -------
#
# tobuildahome
# TITLE (2296): To Build a Home
# AUTHOR: ['endlessblankpages']
# FANDOM: ['One Piece']
#
# TITLE (2297): To Build a Home
# AUTHOR: ['BeanieBaby']
# FANDOM: ['Fantastic Beasts and Where to Find Them (Movies)']
#
# -------
#
# unexpected
# TITLE (2381): Unexpected
# AUTHOR: ['ImagineGeese']
# FANDOM: ['Avatar: The Last Airbender']
#
# TITLE (2382): Unexpected
# AUTHOR: ['FlightInSnow']
# FANDOM: ['Batman - All Media Types', 'Justice League - All Media Types', 'Nightwing (Comics)', 'Young Justice - All Media Types']
#
# -------
#
# wanderer
# TITLE (2420): Wanderer
# AUTHOR: ['cywsphyre', 'cywsaphyre']
# FANDOM: ['Avengers (Marvel) - All Media Types', 'Harry Potter - Fandom', 'Harry Potter - JK Rowling', 'The Avengers (2012)']
#
# TITLE (2421): Wanderer
# AUTHOR: ['cywsaphyre']
# FANDOM: ['Harry Potter - Fandom']
#
# -------

# %%
def merge_values(d1, d2, key):
    """
    Takes two dicts (w/ same keys) and one key name (str).
    Returns one list with all the values of the two given dicts at the key combined, de-dedupped, and sorted.
    """
    if key not in d1 and key not in d2:
        return
    
    v1 = [] if key not in d1 else d1[key]
    v2 = [] if key not in d2 else d2[key]

    v1 = v1 if isinstance(v1, list) else [v1]
    v2 = v2 if isinstance(v2, list) else [v2]

    dedup = list(set(v1 + v2))
    cleaned = [ele for ele in dedup if ele is not None and not pd.isna(ele) and ele != ""]

    return sorted(cleaned)

def merge_dicts(d1, d2):
    """
    Takes 2 dicts.
    Returns one dict with all values for d1 & d2 combined in list form.
    For s5 fic url, keys NOT list: 'primary_version', 'primary_location', 'work_type', 'title', 'fic_id', 'num_appeared', 
        'primary_dtb', 'fic_rating', 'title_str', 'primary_url'
    """
    # Get dict, remove NaN's & de-dup lists
    cols = {key: merge_values(d1, d2, key) for key in d1}

    # Combine values from d1 & d2 for all keys
    sorted_keys = sorted(list(fic1.keys() | fic2.keys()))
    res = {key: combine_dedup(d1, d2, key) for key in sorted_keys}

    not_list_keys = ['primary_version', 'primary_location', 'work_type', 'title', 'primary_dtb', 'title_str', 'primary_url']
    for key in not_list_keys:
        res[key] = res[key][0] if len(res[key]) != 0 else None
        
    res['num_appeared'] = sum(res['num_appeared'])
    res['fic_id'] = d1['fic_id'] if d1['primary_location'] == 'ao3' else d2['fic_id']
    res['fic_rating'] = None if len(res['fic_rating']) == 0 else sum(res['fic_rating'])
    return res

# Testing
fic1 = url_unmerged[1036]
fic2 = url_unmerged[1038]
merge_dicts(fic1, fic2)
# Out:
# {'all_ratings': [],
#  'all_tags': [],
#  'all_urls': ['https://archiveofourown.org/works/14693193',
#   'https://archiveofourown.org/works/14693193/chapters/33951429',
#   'https://www.fanfiction.net/s/10599176/1/Intertwined'],
#  'author': ['BloodyWar2411'],
#  'categories': [],
#  'current_chapter': [],
#  'dtb_types': ['cont_read', 'read'],
#  'fandom': ['Fullmetal Alchemist - All Media Types'],
#  'fandom_type': [],
#  'ffn_date_added': ['4/2/18'],
#  'ffn_date_updated_2-4-23': ['8/5/20'],
#  'fic_id': 14693193,
#  'fic_rating': None,
#  'fic_series': [],
#  'fic_status': [],
#  'in_category': [],
#  'is_backedup': [],
#  'is_bold': [True],
#  'is_bookmarked': [],
#  'is_coffee': [],
#  'is_complete': [],
#  'is_finished_inputting_data': [False],
#  'is_subbed': [],
#  'length': [],
#  'locations': ['ao3', 'ffn_net'],
#  'num_appeared': 5,
#  'primary_dtb': 'read',
#  'primary_location': 'ao3',
#  'primary_source': ['v7_updates', 'v8_ffn_net_account_fic'],
#  'primary_url': 'https://archiveofourown.org/works/14693193',
#  'primary_version': 7.0,
#  'readability_status': ['readable'],
#  'smk_sources': ['v7.1_ffn',
#   'v7_updates',
#   'v8_ffn_net_account_fic',
#   'v8_local_files'],
#  'title': 'Intertwined',
#  'title_str': 'intertwined',
#  'to_read_description': ['???, the core one'],
#  'to_read_rating': [],
#  'version_nums': [7.0, 7.1, 8.0],
#  'work_type': 'fic'}

# %%
# Code to merge duplicates, remove originals, and add merged
dups_to_merge = [['intertwined', 1036, 1038], 
                    ['loyalty', 1229, 1231],
                    ['achildavenged', 46, 47],
                    ['dusktodawn', 586, 587],
                    ['everythingcanchange', 616, 617],
                    ['familybonds', 645, 646],
                    ['foradventureandchaos', 706, 707],
                    ['gaslightingthenecronomicon', 763, 764],
                    ['heavensgarden', 857, 858],
                    ['herphantom', 880, 881],
                    ['imaginaryfriend', 1001, 1002],
                    ['nest', 1335, 1336],
                    ['scorched', 1701, 1702],
                    ['seagullsandbeetles', 1708, 1709],
                    ['spadesonscreen', 1813, 1814],
                    ['standards', 1832, 1833],
                    ['tenyearsdifference', 1936, 1937],
                    ['thegamehasonlyjustbegun', 2025, 2026],
                    ['thelivesworthsaving', 2067, 2068],
                    ['thenightthehouseofcardswasbuilt', 2096, 2097],
                    ['wanderer', 2420, 2421],
                     ['catalysis', 398, 399],
                ]

# Checker
pre_len = len(url_unmerged)

# Merge dicts
merged_dicts = []
inds_remove = []
for title_str, i1, i2 in dups_to_merge:
    # Check getting right fics to merge
    if url_unmerged[i1]['title_str'] != title_str or url_unmerged[i2]['title_str'] != title_str:
        print(f"ERROR: '{title_str}', ({i1}) {url_unmerged[i1]['title_str']}, ({i2}) {url_unmerged[i2]['title_str']}!")

    # Merge dicts
    new_dict = merge_dicts(url_unmerged[i1], url_unmerged[i2])
    merged_dicts.append(new_dict)

    # Get indexes to remove
    inds_remove.append(i1)
    inds_remove.append(i2)
    
# Add new merged dicts to url_unmerged
url_unmerged.extend(merged_dicts)

# Remove original fics (that created merged one)
inds_remove.sort(reverse=True)

for ind in inds_remove:
    url_unmerged.pop(ind)

# %%
# Checking it worked
f"# dups: {len(dups_to_merge)} | pre-len: {pre_len} | post-len: {len(url_unmerged)} (should be: {pre_len-len(dups_to_merge)})"
# Out:
# '# dups: 22 | pre-len: 2620 | post-len: 2598 (should be: 2598)'

# %%
# # Checker - make sure right fics are adding & removed
# dups_strs = [dup[0] for dup in dups_to_merge]

# for name in dups_strs:
#     print(name)
#     for i, fic in enumerate(url_unmerged):
#         if fic['title_str'] == name:
#             print(f"TITLE ({i}): {fic['title']}")
#             print(f"AUTHOR: {fic['author']}")
#             print(f"FANDOM: {fic['fandom']}")
#             print('-------') 
#     print()

# Should print

# %%
# Add numbers to the end of the title_str of duplicates
# Get title_str with more than 1 instance
all_ts = [fic['title_str'] for fic in url_unmerged if fic['title_str'] != ""]
ts_count = Counter(all_ts)
still_doubles = [key for key in ts_count if ts_count[key] > 1]

# Add _num tag on end of duplicates
for title_str in still_doubles:
    count = 1
    for i, fic in enumerate(url_unmerged):
        if fic['title_str'] == title_str:
            url_unmerged[i]['title_str'] = f"{title_str}_{count}"
            count += 1

# %%
# Checker - make sure all title_strs are unique
all_ts = [fic['title_str'] for fic in url_unmerged]
Counter(all_ts)

# Should only have title_str '' have more than one instance
# Out:
# Counter({'': 15,
#          '10reasonsnottofightadragonbirdaguidebyarthurpendragon': 1,
#          '10thingsihateaboutdatingatgusuacademy': 1,
#          '1861c100s60': 1,
#          '30hoursonmillbillillie': 1,
#          '4018': 1,
#          '50heartbeatsawayfromromance': 1,
#          '50waystoloseanarmandalegbyedwardelric': 1,
#          '5timesjasontookcareoftimandonetimetimtookcareofjason': 1,
#          '5timeskurokowishedheneveropenedhisdamnmouth': 1,
#          '5timespetermadetonylaughoutloud': 1,
#          '5timespeterpretendedtobetougherthanhewas': 1,
#          '5timesspidermansavedanavengersassand1timetheysavedhim': 1,
#          '5timestimspendsthenightatwaynemanor1timehecomeshome': 1,
#          '5timestonydidntneedtoworryaboutpeter': 1,
#          '5timestonyforgotpeterwasjustakid': 1,
#          '5timestonyhadtoomuchmoneyandonetimepeterdid': 1,
#          '60years': 1,
#          'abeatingheartofstone': 1,
#          'abirdinthehand': 1,
#          'aboutdamageaboutpainaboutheartache': 1,
#          'absolutelyineffable': 1,
#          'abushelandapeck': 1,
#          'abyssalparadise': 1,
#          'acatcanlookataking': 1,
#          'acceptablebehavior': 1,
#          'accidentallyirresistible': 1,
#          'accordingtoplan': 1,
#          'accountability': 1,
#          'accountingnojutsu': 1,
#          'acertainlevelofsociety': 1,
#          'achangeofperspective': 1,
#          'acivilcombpaign': 1,
#          'acompleteguidetofallinginlove': 1,
#          'aconvergenceoflightning': 1,
#          'acryingshame': 1,
#          'actionsspeaklouderthanwords': 1,
#          'actusfidei': 1,
#          'adecadeinthesun': 1,
#          'adegreeofcompatibility': 1,
#          'adifferentsetofvalues': 1,
#          'adifferentsideofme': 1,
#          'adinfinitummodified': 1,
#          'adisarmingactofloyalty': 1,
#          'adoptedbydefault': 1,
#          'adoptionbydefenestrationorafamilycanbeafoxdemonitsjinchuurikiandthreedozenhighlytrainedassassins': 1,
#          'adragonstreasure': 1,
#          'adropofpoison_1': 1,
#          'adropofpoison_2': 1,
#          'adventuresofshenjiu': 1,
#          'afastcrashcourseinpostmodernlit': 1,
#          'afathersson': 1,
#          'afavoredpeony': 1,
#          'aformalredress': 1,
#          'afoxwithhumaneyes': 1,
#          'aftermath': 1,
#          'afterthestorm': 1,
#          'agentlerlife': 1,
#          'agoodfeeling': 1,
#          'agoodfit': 1,
#          'agoodmythishardtokill': 1,
#          'agoodteacher': 1,
#          'aguidetogettingyourteacheradate': 1,
#          'ahatfashionedfromtinfoil': 1,
#          'ahelpfulfaq': 1,
#          'ahundredspringsfloweasttowardsthesea': 1,
#          'ahundredwinksofsunshine': 1,
#          'ahunterorsomething': 1,
#          'aintnocompassaintnomap': 1,
#          'aizawadefinitelydoesntcare': 1,
#          'aizawashoutasbabysittersclub': 1,
#          'akindofgame': 1,
#          'akisstoturnashesintofire': 1,
#          'alessandra': 1,
#          'alessoninattachment': 1,
#          'alienshammersandmakingamemorablefirstimpression': 1,
#          'alittlesugar': 1,
#          'alittleunsteady': 1,
#          'allbecauseofyouidoright': 1,
#          'allforua': 1,
#          'allgoodthingscomeinthrees': 1,
#          'alligottadoisactnaturally': 1,
#          'allihearareechoes': 1,
#          'allisonargentavenger': 1,
#          'alloldthingsarenewagain': 1,
#          'allouryesterdayshurtmorethanicansay': 1,
#          'allowmetomeltintheheatofyou': 1,
#          'allowonetosee': 1,
#          'allriversflowsafelytosea': 1,
#          'allshewants': 1,
#          'alltheroofsofuncertainty': 1,
#          'alltheyoungdudes': 1,
#          'allthisforaglassofwineandaconversation': 1,
#          'alltogethernow': 1,
#          'allureimmuneharry': 1,
#          'allyouasked': 1,
#          'allyouregivingmeisfriction': 1,
#          'allyourlifeyoulldreamofthis': 1,
#          'almostparadise': 1,
#          'alonebird': 1,
#          'alotuscreatesripples': 1,
#          'alternateforgingmethods': 1,
#          'amandalorianguideonhowtosavethejediinjustthreeeasysteps': 1,
#          'amatchmadeinhellfire': 1,
#          'amatterofperspectivethoughtheveil': 1,
#          'ameditationonrailroading': 1,
#          'ameowmentintime': 1,
#          'americanninjaworrier': 1,
#          'amicroutopiabornastheovertureplays': 1,
#          'amillionbitesmoretillimyours': 1,
#          'aminorsealingmishap': 1,
#          'amushroomaday': 1,
#          'anacttoooftenneglected_1': 1,
#          'anacttoooftenneglected_2': 1,
#          'analphasinstinct': 1,
#          'anatypicalcourtship': 1,
#          'anawkwardencounter': 1,
#          'anawkwardposition': 1,
#          'andgiveallthelovethatyouhaveinyoursoul': 1,
#          'andifirecover': 1,
#          'andihatemyselfbuticouldnthateyou': 1,
#          'andillfollowthelightinyou': 1,
#          'andillreturnfromthewestwithvictoryatmyback': 1,
#          'andimbackwithamadness': 1,
#          'andimremindedofthesimplelifewhereiworkandjustbeused': 1,
#          'andisaytoomuchyeahthatstrue': 1,
#          'anditcomesbackaround': 1,
#          'andnowiseedaylight': 1,
#          'andperhapsthegreatestgriefisbeingleftinauniversewhereyouaregone': 1,
#          'andsuperboymakesthree': 1,
#          'andtheclashofbladesitsagreeting': 1,
#          'andthenmyheartwassoftlikemoonlightbreakingwhitewaves': 1,
#          'andthroughtheirreinsiniceandfirefearcontendedwithdesire': 1,
#          'andwewereinfinite': 1,
#          'andyouneverevenheardaboutmywaitingforyou': 1,
#          'aneasylie': 1,
#          'aneffectivedistraction': 1,
#          'anepicadventure': 1,
#          'aneverfixedmark': 1,
#          'anew': 1,
#          'anewadventure': 1,
#          'aniang': 1,
#          'anidiotsguidetoahappymarriage': 1,
#          'anightattheolstation': 1,
#          'animalinstinct': 1,
#          'aninterestingschoolday': 1,
#          'anirrevocablecondition': 1,
#          'anomaly': 1,
#          'anotherperfectcatastrophe': 1,
#          'anoutsidersperspective': 1,
#          'antarcticadage': 1,
#          'antithesis': 1,
#          'anunexpectedfind': 1,
#          'anunorthodoxadoption': 1,
#          'anymeasureofpeace': 1,
#          'anythingandeverythingcanturnintoapornficevenagoddamnsewer': 1,
#          'anythinglikeme': 1,
#          'aobdrabsfromtumblr': 1,
#          'aperfectstorm': 1,
#          'aperture': 1,
#          'apoundofflesh': 1,
#          'appliedlinguistics': 1,
#          'aprinceindisguise': 1,
#          'apropereducation': 1,
#          'apseudonymtofoolhimhecouldnthavemadeaworsemove': 1,
#          'aq': 1,
#          'aqueenstrialsandhowtospeedrunthem': 1,
#          'aquietlifeofleisure': 1,
#          'aquietnightnotinthecards': 1,
#          'arcoftherevolution': 1,
#          'arcticwolvesmakethebestmediators': 1,
#          'areacryptidupsetnoonebotheredtoinformhimofhistragicbackstory': 1,
#          'areallyprivateperson': 1,
#          'arentimorethaneverything': 1,
#          'areplacementtwicemade': 1,
#          'areudating': 1,
#          'arosebyanyothername': 1,
#          'aroyalsoulmate': 1,
#          'ascensionoftheheart': 1,
#          'asecondchanceforasinisterpersonfullofresentment': 1,
#          'asensiblearrangement': 1,
#          'asevennationarmycouldntholdmeback': 1,
#          'asfarasyouneedtogo': 1,
#          'asgentleasflowers': 1,
#          'ashamelessnightatqinghe': 1,
#          'ashberriesletters': 1,
#          'ashesofthepast': 1,
#          'asistheseamarvelous': 1,
#          'asitwas': 1,
#          'askmenoquestions': 1,
#          'askuntilyourheartgetsitright': 1,
#          'aslightsealingmishap': 1,
#          'asmileandagun': 1,
#          'asongbetweenus': 1,
#          'asongofashandsnow': 1,
#          'assemblyofpainhappinessfeelings': 1,
#          'asthedaysrollon': 1,
#          'astorminthenorth': 1,
#          'astronomyinreverse': 1,
#          'astudyinentropy': 1,
#          'asyouwish': 1,
#          'ataleofcreation': 1,
#          'ataleofearthandfire': 1,
#          'ataleofforutneandsecrets': 1,
#          'atemporarygoodcometothosewhodeserveit': 1,
#          'aterminalcaseofstupidity': 1,
#          'athingofvikings': 1,
#          'athousandmilesupandwereabouttogethigher': 1,
#          'atimelycure': 1,
#          'atloptrialbyfire': 1,
#          'atroopersguidetolightsabermaintenance': 1,
#          'atruthuniversallyacknowledged': 1,
#          'attheendofastormisagoldensky': 1,
#          'authorsofourownfate': 1,
#          'avatartheuntamedwaterbender': 1,
#          'avertinggalacticdestruction': 1,
#          'averyoddfamilyindeed': 1,
#          'avocadosocksandburntpancakes': 1,
#          'awaitinggame': 1,
#          'awakening': 1,
#          'awarlockswish': 1,
#          'awaythingsshouldbe': 1,
#          'aweekisjustsevendaysisntit': 1,
#          'awellwhereinserpentsarecoiled': 1,
#          'awfulwonderful': 1,
#          'awidowswalk': 1,
#          'awildflowercrushedinhand': 1,
#          'awishtochangefate': 1,
#          'awolfamongstlions': 1,
#          'aworldofwaterandcrystal': 1,
#          'ayuanhasatleastthreefriends': 1,
#          'azureandobsidian': 1,
#          'babeinthewoods': 1,
#          'babybirdsandbatcaves': 1,
#          'babyblues': 1,
#          'babyboy': 1,
#          'babyiamplumpandripe': 1,
#          'babyitscoldoutside_1': 1,
#          'babyitscoldoutside_2': 1,
#          'babyonboard': 1,
#          'backslide': 1,
#          'backtheniwasdauntless': 1,
#          'backtowork': 1,
#          'badcompany': 1,
#          'baddecisions': 1,
#          'badtimingtheclockticksinspiteofus': 1,
#          'bagabat': 1,
#          'bakinmagic': 1,
#          'balancing': 1,
#          'balloonman': 1,
#          'bamboofireandink': 1,
#          'bandagedhand': 1,
#          'bargaining': 1,
#          'barter': 1,
#          'basicinstincts': 1,
#          'batoutofhell': 1,
#          'battleplans': 1,
#          'beastmaster': 1,
#          'beautifullyspent': 1,
#          'bebravebetruesavetheempire': 1,
#          'bebyyourside': 1,
#          'becarefulandbefaithful': 1,
#          'becauseicouldnotstopfordeath': 1,
#          'becauseicouldnotstopfordeathhekindlystoppedforme': 1,
#          'becomingthephoenix': 1,
#          'beefconsommé': 1,
#          'behindaclocknolongerchiming': 1,
#          'bellcollar': 1,
#          'bereftindeathlybloom': 1,
#          'bestlaidplans_1': 1,
#          'bestlaidplans_2': 1,
#          'bestlaidplansnotsober': 1,
#          'bethouforthepeople': 1,
#          'betterbegryffindor': 1,
#          'betterthandreams': 1,
#          'betterthantobend': 1,
#          'betterwholethanperfect': 1,
#          'betweenearthandskyagildedlotusblooms': 1,
#          'betweenhiskings': 1,
#          'betweentwobeatinglungs': 1,
#          'betweenyouandobliviontherestandsacat': 1,
#          'beyondredemption': 1,
#          'beyondredemptioniresentall': 1,
#          'biggering': 1,
#          'biggestfan': 1,
#          'bighandsiknowyouretheone': 1,
#          'bigqsbigsix': 1,
#          'bilateral': 1,
#          'bingheandthegreatasselevator': 1,
#          'bingmeisguidetolewdingyourshizun': 1,
#          'birdbybird': 1,
#          'birdsflyineverydirection': 1,
#          'birdsofafeather': 1,
#          'birdsofafeatherorwhatever': 1,
#          'birthright': 1,
#          'bite': 1,
#          'biteme': 1,
#          'bitetodeath': 1,
#          'bitsandpieces': 1,
#          'blackholeheart': 1,
#          'blackholerooms': 1,
#          'blackjack': 1,
#          'blackjadeite': 1,
#          'blacksky': 1,
#          'blackstringofdeath': 1,
#          'bladework': 1,
#          'blessedmoon': 1,
#          'blessingindisguise': 1,
#          'bloodedcrown': 1,
#          'bloodforbloodandwellseewhatemerges': 1,
#          'bloodinthewater': 1,
#          'bloodisnteverythingbutitpaysthebills': 1,
#          'bloodisthicker': 1,
#          'bloodyshowpony': 1,
#          'blue': 1,
#          'blueribbonbunny': 1,
#          'boilingpoint': 1,
#          'bondingrituals': 1,
#          'bondingtimeorsixvillainswhowereslightlylessthanvillainous': 1,
#          'bonusmaterial': 1,
#          'botherwithme': 1,
#          'boundedinanutshellkingofinfinitespace': 1,
#          'boyfriendmaterial': 1,
#          'branch': 1,
#          'braveryandcunning': 1,
#          'breakingtheice': 1,
#          'breathingsjustarhythm': 1,
#          'breathoflife': 1,
#          'brighterdays': 1,
#          'brighteststarinthesky': 1,
#          'brokentrust': 1,
#          'bromance': 1,
#          'brotherhood3zunweek2019day6bodyswitch': 1,
#          'brothers': 1,
#          'brotherscomeinkinds': 1,
#          'brotherwanted': 1,
#          'bruja': 1,
#          'buachaillsciobail': 1,
#          'buckyssunshine': 1,
#          'buildmeariver': 1,
#          'buildyourwingsonthewaydown': 1,
#          'bumpsandbruises': 1,
#          'bureaucraticprocesses': 1,
#          'buriedwiththewildflowers': 1,
#          'burningbrightly': 1,
#          'burningdownthehouse': 1,
#          'burnmewithfire': 1,
#          'burntheworldmakeahome': 1,
#          'burymyheartunderneaththesetrees': 1,
#          'business': 1,
#          'butamongourownselveswellbefreeorthomasandtheislandofthegays': 1,
#          'buthowdoyouknow': 1,
#          'butterfliesandblackbluebirdsonhiatus': 1,
#          'buttherosewasawakeallnightforyoursakeknowingyourpromisetome': 1,
#          'butyoucanreadmymindifeelitallthetime': 1,
#          'butyougottagetupatleastoncemore': 1,
#          'byanyothername_1': 1,
#          'byanyothername_2': 1,
#          'bydegrees': 1,
#          'byomission': 1,
#          'bythesword': 1,
#          'bythewatersedge': 1,
#          'bywirewoodandstake': 1,
#          'cadentibusastris': 1,
#          'cake': 1,
#          'calculation': 1,
#          'callandresponse': 1,
#          'callingthemiddleman': 1,
#          'camerason': 1,
#          'canbetuckedunderyourchin': 1,
#          'cangqiongssecrettointrasectrelations': 1,
#          'caniofferyoualittlesaltforthatwound': 1,
#          'cantreturntowhoiwasbefore': 1,
#          'capacitance': 1,
#          'captaindragon': 1,
#          'cardiacarrest': 1,
#          'carnivore': 1,
#          'carpetbaggers': 1,
#          'carrymehome': 1,
#          'carryonmywaywardson': 1,
#          'castlesintheair': 1,
#          'cataclysm': 1,
#          'catchingbeeswithhoney': 1,
#          'catfight': 1,
#          'catharsis': 1,
#          'catscradle': 1,
#          'catsinthecradle': 1,
#          'caughtbytwo': 1,
#          'caughtinthispoisonedparadise': 1,
#          'causationinstantiation人渣反派自慰系統': 1,
#          'causeforconcern': 1,
#          'certainpoint': 1,
#          'cestlavie': 1,
#          'chalkituptothewilloftheforce': 1,
#          'chancemeeting': 1,
#          'changefatebybeingaggressivelykind': 1,
#          'changeofplans': 1,
#          'cheersandspirits': 1,
#          'childish': 1,
#          'childking': 1,
#          'childlockson': 1,
#          'childrenhypocrisythatswhatigiveyoucantakeitfromme': 1,
#          'childrenofbloodandfortune': 1,
#          'childsplay': 1,
#          'chosenotherwise': 1,
#          'chrysalis': 1,
#          'circadianrhythm': 1,
#          'cirruscloud': 1,
#          'cityofthefutureorthehamdevilau': 1,
#          'civetsthatliveinyourceilingarenotpetsthatyougivenameslikeyao': 1,
#          'claimant': 1,
#          'clarkkentgoestogotham': 1,
#          'cleavetohislike': 1,
#          'closer': 1,
#          'closetohome': 1,
#          'closingtime': 1,
#          'cloudywithachanceofchaos': 1,
#          'clumsyonlygoessofar': 1,
#          'cohabitation': 1,
#          'coldlittleheart': 1,
#          'coloursinyoureyes': 1,
#          'comeawayohumanchild': 1,
#          'comehometome': 1,
#          'comemorningtogetheragain': 1,
#          'comesroundinanotherform': 1,
#          'cometogether': 1,
#          'comingdownisthehardestthing': 1,
#          'commoncents': 1,
#          'communicatelearntouseyourwordssowecan': 1,
#          'company': 1,
#          'companyiscoming': 1,
#          'complicatedbutonlywithyou': 1,
#          'complicatedcreation': 1,
#          'complimentsthatssuspicious': 1,
#          'composedofus': 1,
#          'congratulationsyouvewonclickheretoclaimyourprize': 1,
#          'consequencestoeveryinaction': 1,
#          'considerthewildflowers': 1,
#          'constructivecriticism': 1,
#          'consumingshadows': 1,
#          'contemplatethedarknesscrawlyourwayout': 1,
#          'content': 1,
#          'contract': 1,
#          'contractslawyersandbusinessmen': 1,
#          'control': 1,
#          'convergence': 1,
#          'cookiepredictions': 1,
#          'corethievinghand': 1,
#          'corneredanimalsbeartheirteeth': 1,
#          'correspondence': 1,
#          'cosmicstrings': 1,
#          'couldthisbeloveatfirstsightorshouldiwalkbyagain': 1,
#          'counttheways': 1,
#          'courageofthestars': 1,
#          'courtingdemons': 1,
#          'courtingoftheconsort': 1,
#          'courtship': 1,
#          'crackedmirror': 1,
#          'crazyrichcultivators': 1,
#          'creation': 1,
#          'creationbothhauntedandholy': 1,
#          'creaturesinneedofhelp': 1,
#          'crisisahotone': 1,
#          'crossdressing': 1,
#          'crossingtheline': 1,
#          'crownedingloryfearnomore': 1,
#          'crustandsugarover': 1,
#          'crymeariver': 1,
#          'cryptidsarenotpermittedinthecloudrecesses': 1,
#          'cultivateslowlifeonamonsterinfestedmountain': 1,
#          'cultivatingtobecomehuman': 1,
#          'cultivationunsolvedtheuncleanrealmspecial': 1,
#          'culturalexchange': 1,
#          'curinganailment': 1,
#          'curiositykillsthecatbutsatisfactionbringsitback': 1,
#          'cursed': 1,
#          'cursedcouple': 1,
#          'customerserviceinthefoodindustry': 1,
#          'cuterobotweird': 1,
#          'cutfromthesamecloth': 1,
#          'cuthimoutinlittlestars': 1,
#          'daddycool': 1,
#          'damageddefenders': 1,
#          'damiansfirstdayasceowithbenefits': 1,
#          'damnvongolabackatitagainwiththememories': 1,
#          'dangerous': 1,
#          'dansemacabrefirstdance': 1,
#          'darkmatter': 1,
#          'darknessupontheland': 1,
#          'datenight': 1,
#          'dawniscomingopenyoureyes': 1,
#          'daydream': 1,
#          'dearlydeparted': 1,
#          'dearorder': 1,
#          'deathofaghost': 1,
#          'deathwillcomeandsaveusall': 1,
#          'delicacy不懂輪迴': 1,
#          'delightinmisery': 1,
#          'delinquent': 1,
#          'deluxesystem20coopmode': 1,
#          'deprived': 1,
#          'dermabrasion': 1,
#          'desireinhisteeth': 1,
#          'destroyed': 1,
#          'detainment': 1,
#          'devillikeme': 1,
#          'diamondstarhalo': 1,
#          'diasporasblue': 1,
#          'dibs': 1,
#          'didyouheartheoneaboutmyeighthundredsiblings': 1,
#          'differentloveslooknotthesame': 1,
#          'diggingforthebonesbypaganaidd': 1,
#          'digginggraves': 1,
#          'dingdongdingdongdingdongdingbananaphoneee': 1,
#          'diogeneswhatmakesaman': 1,
#          'dirtandashesortheoneandahalfbodyproblem': 1,
#          'dirtycrimeboys': 1,
#          'dirtyhandsregardless': 1,
#          'disasster': 1,
#          'discendodocemus': 1,
#          'disconnectedconduitthearchivedversion': 1,
#          'discordantrhapsody': 1,
#          'disillusionbyhermionegranger': 1,
#          'distance': 1,
#          'divefordreams': 1,
#          'divergentbindings': 1,
#          'divergingpaths': 1,
#          'doctrine': 1,
#          'dodgingwitchesandstealingwitchesrevengeisbestservedraw': 1,
#          'doeeyed': 1,
#          'doeskin': 1,
#          'doesntwashout': 1,
#          'doesyouramberheartbleedpurplegold': 1,
#          'domesticfarmingsim': 1,
#          'dominoes': 1,
#          'donoharmtakenoshit': 1,
#          'donotmeddle': 1,
#          'donotmeddleintheaffairsofdragonsforyouarecrunchyandtastegoodwithketchup': 1,
#          'dontask': 1,
#          'dontcallbatman': 1,
#          'dontforgettobreathe': 1,
#          'dontfuckwithfloriststheyllfuckyouup': 1,
#          'dontgetmadgeteven': 1,
#          'dontjudgeabookbyitscoverespeciallyifthebookisapapapanovel': 1,
#          'dontkissandtell': 1,
#          'dontletthemthrowmeaway': 1,
#          'dontputouttillthe3rddate': 1,
#          'doover': 1,
#          'doubleblind': 1,
#          'doubletrouble': 1,
#          'doubtinggetsyouplaces': 1,
#          'douexpectmeagaytoremembereverythingiwrite': 1,
#          'doyouneedanybody': 1,
#          'doyourealizeidontwantyoutoapologize': 1,
#          'doyouwanttostayforever': 1,
#          'dragonlord': 1,
#          'dreamalittledreamofme': 1,
#          'dreaminmysoulandiwontletitgo': 1,
#          'dreamofafuneralhearofamarriage': 1,
#          'dreamsthathadnevercometrue': 1,
#          'driftingback': 1,
#          'drowninginmysoul': 1,
#          'drowninginyou': 1,
#          'dualcultivationordate': 1,
#          'dudebro': 1,
#          'duesouth': 1,
#          'dumbandditzy': 1,
#          'duplicityandallitscoldcomforts': 1,
#          'dutygivenchance': 1,
#          'earlybirdgetstheworm': 1,
#          'eartothewall': 1,
#          'eastofthesunandwestofthemoon': 1,
#          'eightprinciplesofyong': 1,
#          'elderanaesthetic': 1,
#          'electricboogaloo': 1,
#          'emergencycontacts': 1,
#          'emptycuppourmesomemore': 1,
#          'emrysrevealed': 1,
#          'endlesspossibilities': 1,
#          'engineheart': 1,
#          'enjoythesilence': 1,
#          'entirelyoutofspite': 1,
#          'eonsaremerechildsplay': 1,
#          'equivalentexchange': 1,
#          'eraserheadsfirstautograph': 1,
#          'etiquettelessonstypeatypeb': 1,
#          'evenbatmanhashislimitsorhowthemostwellkeptsecretinthejusticeleagueisrevealedbecauseoflasagna': 1,
#          'evenifyoudieevenifyouarereborn': 1,
#          'everafter': 1,
#          'everafterandthensome': 1,
#          'everybodylovesprompto': 1,
#          'everybodylovesthinmints': 1,
#          'everybodytalkstoomuch': 1,
#          'everybodywantsyou': 1,
#          'everyplaneteverystareverysinglegrainofsand': 1,
#          'everystarinthesky': 1,
#          'everythingieverlostnowhasbeenreturned': 1,
#          'everythingisgoingtoplanandotherlies': 1,
#          'everythingnow': 1,
#          'excessivelyclever': 1,
#          'exclusivelyyours': 1,
#          'exclusivity': 1,
#          'executiveassistanttothebatman': 1,
#          'existanceisanact': 1,
#          'exitstrategy': 1,
#          'expansion': 1,
#          'extension': 1,
#          'extraordinaryattorneywangji': 1,
#          'facade': 1,
#          'facedeathinthehope': 1,
#          'facethemonstersthatareatourdoor': 1,
#          'facetoface': 1,
#          'facingthemusic': 1,
#          'fairtrade': 1,
#          'fairydanceofdeath': 1,
#          'fairygodbrother': 1,
#          'fairyprincessproblems': 1,
#          'fakesugar': 1,
#          'falling': 1,
#          'fallingleavesofevergreentrees': 1,
#          'fallingwithoutcaution': 1,
#          'falloutboysoicanfallintoyou': 1,
#          'familiarbutthistimeivehadsomepractice': 1,
#          'familydynamics': 1,
#          'familygivesustwothingsoneisrootstheotheriswings': 1,
#          'familyreunions': 1,
#          'familyvalues': 1,
#          'fantasticelvesandwheretofindthem': 1,
#          'farlongerthanforever': 1,
#          'fartooyoungtodie': 1,
#          'fatherhood': 1,
#          'fathommeout': 1,
#          'favor': 1,
#          'favourandfate': 1,
#          'feathersfabricfatherfiguresandotherfwordsonhawksmind': 1,
#          'feedingtherumormill': 1,
#          'feedtheflamecausewecantletgo': 1,
#          'feelingnotexactlydifferentnorreallythesame': 1,
#          'feeltheworldsodifferently': 1,
#          'feelyourpain': 1,
#          'feelyourwayhome': 1,
#          'felinecatastrophe': 1,
#          'feral': 1,
#          'fiftysnapshotssunandsky': 1,
#          'fightorflyte': 1,
#          'figureskatesandhockeyblades': 1,
#          'filledlikeaflower': 1,
#          'finaltemptation': 1,
#          'financialcrimefuntimewithmengyaoandjinzixuan': 1,
#          'findastartosoldieron': 1,
#          'finderskeepers': 1,
#          'findinghome': 1,
#          'findingmerlin': 1,
#          'findingonesownpath': 1,
#          'findingthenobleinnobility': 1,
#          'findingyouagain': 1,
#          'findmeawhiteknightcloakedinblack': 1,
#          'findthenewworldinyou': 1,
#          'findussidebyside': 1,
#          'finelassniceasscatearsandsheuwu': 1,
#          'fireofthename': 1,
#          'firespreadingallaround': 1,
#          'firstcontactorthefourbodyproblem': 1,
#          'fiveheartstomakehimwhole': 1,
#          'fivestimesjasontoddsavedhisbrothersandonetimetheysavedhim': 1,
#          'fivetimeshenryscompetencyturnedalexonandtheonetimeitturnedhimintoapileofromanticgoo': 1,
#          'fivetimesniehuaisangisgladweiwuxianexistsandonetimehedefinitelyisnt': 1,
#          'fivetimesoneoftheavengersmetoneofthewaynekids': 1,
#          'fivetimesstilespulledonefromtheovenandonetimesomebodyelsedid': 1,
#          'fivetimestheleveragecrewwasnotingothamnoreallytheywerentno': 1,
#          'flankingmaneuver': 1,
#          'flightrisk': 1,
#          'flowersforthesickanddead': 1,
#          'flowingwaters': 1,
#          'flowlikefire': 1,
#          'flyingsolo': 1,
#          'flyingwithflaws': 1,
#          'followtheleader': 1,
#          'foolmeonce_1': 1,
#          'foolmeonce_2': 1,
#          'foolsghoulsandgravemistakes': 1,
#          'foolshope': 1,
#          'foragoodtimecall': 1,
#          'forahundredvisionsandrevisions': 1,
#          'forallthosepagesthumbed': 1,
#          'forbetterorforworse': 1,
#          'foreignbodiestaketheirtoll': 1,
#          'foreignrecruit': 1,
#          'foreignrecruitsnippets': 1,
#          'foreverandeverandeverandever': 1,
#          'forfeit': 1,
#          'forforgivenessyoucouldalwayspray': 1,
#          'forgeddestiny': 1,
#          'forgetful': 1,
#          'forgetheironinyourveins': 1,
#          'forginganewageisnevereasy': 1,
#          'forhehasaboytoleanon': 1,
#          'forhim': 1,
#          'formanalliance': 1,
#          'formidable': 1,
#          'forresearchpurposesonly': 1,
#          'fortheonesleftbehind': 1,
#          'fortherightprice': 1,
#          'forthosewhowait': 1,
#          'fortress': 1,
#          'foruschildthestarsrefusetoshine': 1,
#          'forwantofacoffee': 1,
#          'forwardingaddress': 1,
#          'forwhenithurts': 1,
#          'foryoumydearidwaitforever': 1,
#          'foundationsofgooddiplomacy': 1,
#          'foxstongueandkirinsbone': 1,
#          'fracturedfairytale': 1,
#          'fracturewhatifbatdad': 1,
#          'fragrance': 1,
#          'freefall': 1,
#          'freefromfire': 1,
#          'friendlyneighbourhoodfalconmage': 1,
#          'friendshipismagic': 1,
#          'friendswithbenefits': 1,
#          'frighteningbutnotafraid': 1,
#          'fromafar': 1,
#          'fromashestonew': 1,
#          'fromheretoneptune': 1,
#          'frommuddywaters': 1,
#          'fromrichestorags': 1,
#          'fromthemouthsofbabes': 1,
#          'fromtheshadows': 1,
#          'fromthestart': 1,
#          'fromthetopthistimewithpersonality': 1,
#          'frost': 1,
#          'frostbite': 1,
#          'frostformedflameforged': 1,
#          'fruitbats': 1,
#          'fuckingraptorbrain': 1,
#          'fulldisclosure': 1,
#          'gardenorgraveyard': 1,
#          'gaveyoursmiletome': 1,
#          'gelosaþinécnesse': 1,
#          'gemini': 1,
#          'genderconfusion': 1,
#          'getalittlebitcloser': 1,
#          'getbywithalittlehelp': 1,
#          'getintheactionfeeltheattraction': 1,
#          'gettingheavy': 1,
#          'gezellig': 1,
#          'ghost': 1,
#          'ghostfromtheotherside': 1,
#          'ghostlydelivery': 1,
#          'ghostsshouldnt': 1,
#          'giantsofindustry': 1,
#          'giftsfromadragon': 1,
#          'girlbossgatekeep': 1,
#          'gitgud': 1,
#          'giveaninchtakeamile': 1,
#          'givemeachancetofall': 1,
#          'givethankstobrokenbones': 1,
#          'giveyouallthatiam': 1,
#          'glitterslikegold': 1,
#          'glorifiedbabysitter': 1,
#          'glory': 1,
#          'godhelpyoudumbboy': 1,
#          'godownwithyou': 1,
#          'godsofwoodandstone': 1,
#          'gohomefindyourselfhappy': 1,
#          'goingoffbook': 1,
#          'goingoncegoingtwice': 1,
#          'golden': 1,
#          'goldenwhenthedaymetthenight': 1,
#          'goldfromlead': 1,
#          'goncharovfilm': 1,
#          'gonebutnotburied': 1,
#          'gonetothedogs': 1,
#          'gonnabeabetteroneathousandmilestoyourdoor': 1,
#          'gonnabeawinner': 1,
#          'goodboys': 1,
#          'goodinfluence': 1,
#          'goodlives': 1,
#          'goodvibrations': 1,
#          'gotaheartinmeiswear': 1,
#          'gothambanksy': 1,
#          'gothamcitysirensspoiled': 1,
#          'gothamghoul': 1,
#          'gothamistrending': 1,
#          'gothamstoptenmemes': 1,
#          'gotwithoutmerit': 1,
#          'gowherethestolenrosesgrow': 1,
#          'grandchildren': 1,
#          'grandescape': 1,
#          'graverobber': 1,
#          'green': 1,
#          'greenshadows': 1,
#          'greensogreenistherivergrass': 1,
#          'gringottslesserknownbranch': 1,
#          'groundrules': 1,
#          'grow': 1,
#          'growbeyond': 1,
#          'growingoldwithyou': 1,
#          'growingup': 1,
#          'growthpains一種修為': 1,
#          'guaranteedtoblowyourmind': 1,
#          'guessinggame': 1,
#          'guessyourtrajectory': 1,
#          'guillotine_1': 1,
#          'guillotine_2': 1,
#          'guiltfordreaming': 1,
#          'halasana': 1,
#          'halcyon': 1,
#          'halfintheshadowshalfburnedinflames': 1,
#          'halfofwinter': 1,
#          'hallowedground': 1,
#          'hamartiatheherosfatalflaw': 1,
#          'hamsterbeam': 1,
#          'handfullofsandheartfullofpearls': 1,
#          'happilyeverafter': 1,
#          'happyaccidents': 1,
#          'hardreset': 1,
#          'hardtotiedown': 1,
#          'harrypotterandtheeasternsage': 1,
#          'harrypotterinthecityofangels': 1,
#          'hatchling': 1,
#          'haveitoldyouaboutminnie': 1,
#          'haven': 1,
#          'havingameparty': 1,
#          'heardmelodiesaresweetbutthoseunheardaresweeter': 1,
#          'heartofkyber': 1,
#          'heartsbane': 1,
#          'heavenlydelights': 1,
#          'heavenlyskypillarredux': 1,
#          'heirship': 1,
#          'heknows': 1,
#          'heldtogetherbyspiderwebs': 1,
#          'hellforthecompany': 1,
#          'hellooceanmyoldfriend': 1,
#          'helpisontheway': 1,
#          'helpmybossisabitch': 1,
#          'helpmydadisfuckingsomeonemyage': 1,
#          'helpwantedbutnotreally': 1,
#          'hereagainspiritsriseunbroken': 1,
#          'herearethewordsthatileftforyou': 1,
#          'herebedragons': 1,
#          'heresthedooryouhavetostepthrough': 1,
#          'heresthepartwhereimakeajokeaboutrosesright': 1,
#          'heretherebedragons': 1,
#          'hereticpride': 1,
#          'herewithme': 1,
#          'herkingdomasgreat': 1,
#          'hermionegrangershogwartscrammerfordelinquentsontherun': 1,
#          'heromartyridiot': 1,
#          'heroofwar': 1,
#          'hesakillerqueensunflowerguillotine': 1,
#          'hesnotasidekickhesaminion': 1,
#          'heyheyyouyou': 1,
#          'heyyouwiththeprettyfacewelcometothehumanrace': 1,
#          'hiddeninplainsight': 1,
#          'hideofalifewar': 1,
#          'hidingintheleaves': 1,
#          'highriskoccupation': 1,
#          'hisuntamedheart': 1,
#          'hitchups': 1,
#          'hitemupstyle': 1,
#          'holdmeclosetoyourbeatingheart': 1,
#          'holdontomeaswego': 1,
#          'hollow': 1,
#          'home': 1,
#          'homealonetimdrake': 1,
#          'homeandhearth': 1,
#          'homebodies': 1,
#          'homecoming': 1,
#          'homesteady': 1,
#          'honeyandmagic': 1,
#          'honoramongthieves': 1,
#          'honoryourenemy': 1,
#          'honōka': 1,
#          'hopeisthethingwithfeathers': 1,
#          'hopelesscase': 1,
#          'hopeuponaflower': 1,
#          'horizonstardriven': 1,
#          'horns': 1,
#          'hotandcold': 1,
#          'hotforteacher': 1,
#          'hotnecromancersinglesseekingdomdaddiesinyourarea': 1,
#          'howaboutthat': 1,
#          'howcompetitionworks': 1,
#          'howeggsymetharryastoldthroughaseriesofsoulmarks': 1,
#          'howfineyoulookwhendressedinrage': 1,
#          'howharrybecamexanxusbabysitter': 1,
#          'hownottoadoptachild': 1,
#          'hownottocourtaveretianprince': 1,
#          'howtobeaheartbreaker': 1,
#          'howtocareforyouromegashixiong': 1,
#          'howtoderailtheplotlikearesponsibleteacher': 1,
#          'howtodesignyourownprosthesisandturntheprojectintoabondingexperience': 1,
#          'howtofileform39b': 1,
#          'howtofinishyourbucketlistbeforeyoudieaguidefromkaeyaalberich': 1,
#          'howtoforgiveandforget': 1,
#          'howtogetridofamopeydemonlord': 1,
#          'howtokeepyourdiplomaticassetcloseandyourweiyingcloserbyhisexcellency': 1,
#          'howtokillwhatyoucantcatch': 1,
#          'howtomakedarthvaderdohistaxesadocumentationbyoneaccountantwhoisnotpaidenough': 1,
#          'howtoproperlycareforyourbabyflash': 1,
#          'howtoreinventthestormtrooperarmortomakeyoursurrogatefatherproudandshutthenaysayersupforfunandprofit': 1,
#          'howtosmilewithbloodyteeth': 1,
#          'howtostopbeingstrungalongbyaguygetwhatyoudeserve5stepstoaseriousrelationship': 1,
#          'howtotameahulijing': 1,
#          'howtotrainyourmers': 1,
#          'howtotrainyourshenqingqiu': 1,
#          'howtowinfriendsinfluencepeople': 1,
#          'howwemetyourmother': 1,
#          'humansdemonsandeverythinginbetween': 1,
#          'hungryforapoke': 1,
#          'huntingfordignity': 1,
#          'huntingpains': 1,
#          'hurt': 1,
#          'hush': 1,
#          'hushnowyouwerelostbutnowyourefound': 1,
#          'hustlingforthegoodlife': 1,
#          'ianwhiteandtherolodexofdoom': 1,
#          'iaskedforamonsterandyougavemeafairytale': 1,
#          'ibikisapprentice': 1,
#          'ibtuurjatnetuurashadkyramur': 1,
#          'icanhearyou': 1,
#          'icebreaker': 1,
#          'icequeen': 1,
#          'icingthecherry': 1,
#          'icouldbeadamselandimoftenindistressbuticanhandleitsohaveanicedayandmovethefuckon': 1,
#          'icouldbeyourbabytonight': 1,
#          'icyheat': 1,
#          'identitycrisis': 1,
#          'idgivemyallforyourlove': 1,
#          'ididitmywaybaby': 1,
#          'ididntsignupforthis': 1,
#          'idontevertrustbutistillchooseyou': 1,
#          'ifamansbestfriendisadogwhatsahobbits': 1,
#          'ifeelyourwarmthanditfeelslikehome': 1,
#          'ifhappinessstartswithyouwhydoesminestartwithu': 1,
#          'ifhearexecuteordersixtysix': 1,
#          'ifhistoryisdeadandgone': 1,
#          'ifieverweretoloseyouidsurelylosemyself': 1,
#          'ifiwasblindfoldedidstillfindmywaytoyou': 1,
#          'ifiwereawere': 1,
#          'ifoundyoutwice': 1,
#          'ifthecostumefits': 1,
#          'ifthemstherules': 1,
#          'iftheseascatchfiretrustyourheart': 1,
#          'ifuckedmysexdollanditcametolife': 1,
#          'ifwecouldgobackidchangetheworldforyou': 1,
#          'ifyougetlostyoucanalwaysbefound': 1,
#          'ifyoulovemeletmeknow': 1,
#          'ifyourelookingforjesusthengetonyourknees': 1,
#          'ifyourestillwaiting': 1,
#          'igneous': 1,
#          'ignorethepreviousmessageordont': 1,
#          'ihavebeenselfishtoo': 1,
#          'ihavedrunkandseenthespider': 1,
#          'iholdwiththosewhofavorfire_1': 1,
#          'iholdwiththosewhofavorfire_2': 1,
#          'iknowthatitswrongthatidontwantittoend': 1,
#          'ilikeyoubarb': 1,
#          'illalwaysprotectyou': 1,
#          'illbeyourboybackstage': 1,
#          'illcountthedaystilliholdyoumyheartwontrestuntilido': 1,
#          'illkeepyousafeherewithme': 1,
#          'illorbityourflickeringstar': 1,
#          'illsleepwhenimdeadorclosetoit': 1,
#          'illtakemytimeandmakeitlast': 1,
#          'illtaketheverdictcauseivedonethecrime': 1,
#          'illwriteyouaniou': 1,
#          'ilookedatyouandsawforever': 1,
#          'imaybeadumbassbutimnotstupid': 1,
#          'imeasureeverygriefimeet': 1,
#          'imfallingforyoureyesbuttheydontknowmeyet': 1,
#          'immutability': 1,
#          'imnotsupposedtotalktostrangers': 1,
#          'imnotyourfakeboyfriend': 1,
#          'impenetrablewalls': 1,
#          'impostorsyndrome': 1,
#          'impressionsawreckagesidefic': 1,
#          'imprettysuretimstealsclothesanelaborationintheformofalongfic': 1,
#          'imsippinteainyohood': 1,
#          'inanotherlife': 1,
#          'inanotherlifetime': 1,
#          'inbondandblood': 1,
#          'incomplete': 1,
#          'ineedmyspace': 1,
#          'inertia': 1,
#          'inevershouldhavejoined': 1,
#          'inforapennyinforapound': 1,
#          'inhibitions': 1,
#          'inhiselements': 1,
#          'inimitable': 1,
#          'initiative': 1,
#          'inlabyrinthsofreflections': 1,
#          'inlittlewayswheneverythingstays': 1,
#          'inloveandwar': 1,
#          'inneedofaproperhug': 1,
#          'inourheartssomeancientsong': 1,
#          'inplainsight': 1,
#          'insicknesshealthandmurder': 1,
#          'inspirationbottleneck': 1,
#          ...})

# %% [markdown]
# ### Combining s5 fic url + text

# %%
def clean_authors(author_list):    
    # Get all unique, lowercase author names
    author_lower = [author.lower() for author in author_list]
    unique = list(set(author_lower))

    # For each unique author, get one author name (preferrably one with uppercase in it)
    clean_authors = []
    for author_name in unique:
        all_authors = []
        best = author_name # save name with uppercase in it, if possible
        for author2 in author_list:
            if author2.lower() == author_name:
                for char in author2:
                    if char.isupper():
                        best = author2
                        break

        clean_authors.append(best)
    return clean_authors

for i, fic in enumerate(url_unmerged):
    url_unmerged[i]['author'] = clean_authors(url_unmerged[i]['author'])

for i, fic in enumerate(text_unmerged):
    text_unmerged[i]['author'] = clean_authors(text_unmerged[i]['author'])

# %%
url_unmerged
# Out:
# [{'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 13142217,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/13142217',
#   'all_urls': ['https://archiveofourown.org/works/13142217']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 13354242,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/13354242',
#   'all_urls': ['https://archiveofourown.org/works/13354242']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 16421201,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/16421201',
#   'all_urls': ['https://archiveofourown.org/works/16421201']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 23956966,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/23956966',
#   'all_urls': ['https://archiveofourown.org/works/23956966']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 26106754,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/26106754',
#   'all_urls': ['https://archiveofourown.org/works/26106754/chapters/63503671']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 27470875,
#   'num_appeared': 2,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/27470875',
#   'all_urls': ['https://www.archiveofourown.org/works/27470875',
#    'https://archiveofourown.org/works/27470875']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 27688829,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['hidden'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'MyWeirdAttributeError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/27688829',
#   'all_urls': ['https://archiveofourown.org/works/27688829']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 29632908,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/29632908',
#   'all_urls': ['https://archiveofourown.org/works/29632908/chapters/72850875']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 30217674,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/30217674',
#   'all_urls': ['https://archiveofourown.org/works/30217674/chapters/74459403']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 30879626,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/30879626',
#   'all_urls': ['https://archiveofourown.org/works/30879626']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 32239345,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/32239345',
#   'all_urls': ['https://archiveofourown.org/works/32239345']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 32509690,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/32509690',
#   'all_urls': ['https://archiveofourown.org/works/32509690']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 39788985,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/39788985',
#   'all_urls': ['https://archiveofourown.org/works/39788985']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 40936332,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/40936332',
#   'all_urls': ['https://archiveofourown.org/works/40936332']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': [],
#   'title': '',
#   'author': [],
#   'fic_id': 41557206,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['not_found'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'error': 'InvalidIdError',
#   'title_str': '',
#   'primary_url': 'https://archiveofourown.org/works/41557206',
#   'all_urls': ['https://archiveofourown.org/works/41557206']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Merlin (TV)'],
#   'title': '10 Reasons Not to Fight a D̶r̶a̶g̶o̶n̶ Bird (a Guide by Arthur Pendragon)',
#   'author': ['CaffeinatedFlumadiddle'],
#   'fic_id': 23321323,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['hidden'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '10reasonsnottofightadragonbirdaguidebyarthurpendragon',
#   'primary_url': 'https://archiveofourown.org/works/23321323',
#   'all_urls': ['https://archiveofourown.org/works/23321323']},
#  {'primary_version': 7.0,
#   'version_nums': [8.0, 7.0],
#   'primary_source': 'v7_updates',
#   'smk_sources': ['v7_updates', 'v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['陈情令 | The Untamed (TV)'],
#   'title': '10 Things I Hate About Dating at Gusu Academy',
#   'author': ['KouriArashi'],
#   'fic_id': 32511868,
#   'num_appeared': 3,
#   'primary_dtb': 'to_read',
#   'dtb_types': ['to_read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': ['59k, by KouriArashi, XiYao, class issues'],
#   'to_read_rating': [],
#   'title_str': '10thingsihateaboutdatingatgusuacademy',
#   'primary_url': 'https://archiveofourown.org/works/32511868',
#   'all_urls': ['https://archiveofourown.org/works/32511868/chapters/80638279',
#    'https://archiveofourown.org/works/32511868']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Star Wars - All Media Types',
#    'Star Wars Prequel Trilogy',
#    'Star Wars: The Clone Wars (2008) - All Media Types'],
#   'title': '1861 c.100 s.60',
#   'author': ['qigiined'],
#   'fic_id': 37536817,
#   'num_appeared': 2,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '1861c100s60',
#   'primary_url': 'https://archiveofourown.org/works/37536817',
#   'all_urls': ['https://archiveofourown.org/works/37536817/chapters/93689596',
#    'https://archiveofourown.org/works/37536817']},
#  {'primary_version': 7.0,
#   'version_nums': [8.0, 7.0],
#   'primary_source': 'v7_updates',
#   'smk_sources': ['v7_updates', 'v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Star Wars - All Media Types',
#    'Star Wars Prequel Trilogy',
#    'Star Wars: The Clone Wars (2008) - All Media Types'],
#   'title': '30 hours on Millbillillie',
#   'author': ['Maddy_B'],
#   'fic_id': 28836627,
#   'num_appeared': 2,
#   'primary_dtb': 'to_read',
#   'dtb_types': ['to_read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': ['17k Cody/Obiwan, troopers + Anakin drunk beach party'],
#   'to_read_rating': [],
#   'title_str': '30hoursonmillbillillie',
#   'primary_url': 'https://archiveofourown.org/works/28836627',
#   'all_urls': ['https://archiveofourown.org/works/28836627']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['陈情令 | The Untamed (TV)',
#    '魔道祖师 - 墨香铜臭 | Módào Zǔshī - Mòxiāng Tóngxiù',
#    '魔道祖师 | Módào Zǔshī (Cartoon)'],
#   'title': '4018',
#   'author': ['sweetlolixo'],
#   'fic_id': 38720787,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '4018',
#   'primary_url': 'https://archiveofourown.org/works/38720787',
#   'all_urls': ['https://archiveofourown.org/works/38720787']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Harry Potter - J. K. Rowling'],
#   'title': '50 Heartbeats Away From Romance',
#   'author': ['RenderedReversed'],
#   'fic_id': 1591592,
#   'num_appeared': 2,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '50heartbeatsawayfromromance',
#   'primary_url': 'https://archiveofourown.org/works/1591592',
#   'all_urls': ['https://archiveofourown.org/works/1591592/chapters/3383591',
#    'https://archiveofourown.org/works/1591592']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Fullmetal Alchemist (Anime 2003)',
#    'Fullmetal Alchemist - All Media Types',
#    'Fullmetal Alchemist: Brotherhood & Manga'],
#   'title': '50 ways to lose an arm and a leg, by Edward Elric',
#   'author': ['Kastaborous'],
#   'fic_id': 39529128,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '50waystoloseanarmandalegbyedwardelric',
#   'primary_url': 'https://archiveofourown.org/works/39529128',
#   'all_urls': ['https://archiveofourown.org/works/39529128']},
#  {'primary_version': 7.0,
#   'version_nums': [8.0, 7.0],
#   'primary_source': 'v7_updates',
#   'smk_sources': ['v7_updates', 'v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Batman - All Media Types'],
#   'title': '5 times Jason took care of Tim, and One Time Tim took care of Jason',
#   'author': ['FluffyPuffySheeps'],
#   'fic_id': 24613408,
#   'num_appeared': 3,
#   'primary_dtb': 'to_read',
#   'dtb_types': ['to_read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '5timesjasontookcareoftimandonetimetimtookcareofjason',
#   'primary_url': 'https://archiveofourown.org/works/24613408',
#   'all_urls': ['https://archiveofourown.org/works/24613408/chapters/59460730',
#    'https://archiveofourown.org/works/24613408']},
#  {'primary_version': 7.0,
#   'version_nums': [7.0],
#   'primary_source': [],
#   'smk_sources': ['v7_toread'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ["Kuroko no Basuke | Kuroko's Basketball"],
#   'title': '5 times Kuroko wished he never opened his damn mouth',
#   'author': ['highboys'],
#   'fic_id': 547880,
#   'num_appeared': 1,
#   'primary_dtb': 'to_read',
#   'dtb_types': ['to_read'],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': ['re'],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': ['1'],
#   'title_str': '5timeskurokowishedheneveropenedhisdamnmouth',
#   'primary_url': 'https://archiveofourown.org/works/547880',
#   'all_urls': ['https://archiveofourown.org/works/547880']},
#  {'primary_version': 7.0,
#   'version_nums': [7.1, 7.0],
#   'primary_source': 'v7_ffn',
#   'smk_sources': ['v7_ffn', 'v7.1_ffn'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Spider-Man - All Media Types'],
#   'title': '5 Times Peter Made Tony Laugh Out Loud',
#   'author': ['grilledcheesing'],
#   'fic_id': 11592432,
#   'num_appeared': 2,
#   'primary_dtb': 'read',
#   'dtb_types': ['read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [True],
#   'is_subbed': [False],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': ['FALSE'],
#   'categories': ['crack_humor,famil_dynamic'],
#   'current_chapter': [],
#   'all_tags': ['.Humor,.Family'],
#   'fic_rating': 2.0,
#   'all_ratings': [2.0],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '5timespetermadetonylaughoutloud',
#   'primary_url': 'https://archiveofourown.org/works/11592432',
#   'all_urls': ['https://www.archiveofourown.org/works/11592432/chapters/26054868']},
#  {'primary_version': 7.0,
#   'version_nums': [7.0],
#   'primary_source': [],
#   'smk_sources': ['v7_toread'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Avengers (Marvel) - All Media Types',
#    'Spider-Man - All Media Types'],
#   'title': '5 Times Peter Pretended To Be Tougher Than He Was',
#   'author': ['grilledcheesing'],
#   'fic_id': 11987034,
#   'num_appeared': 1,
#   'primary_dtb': 'to_read',
#   'dtb_types': ['to_read'],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': ['-'],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': ['hurt Peter, 9k kudos'],
#   'to_read_rating': ['2'],
#   'title_str': '5timespeterpretendedtobetougherthanhewas',
#   'primary_url': 'https://archiveofourown.org/works/11987034',
#   'all_urls': ['https://archiveofourown.org/works/11987034/chapters/27116316']},
#  {'primary_version': 7.0,
#   'version_nums': [7.0],
#   'primary_source': [],
#   'smk_sources': ['v7_toread'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Avengers (Marvel) - All Media Types',
#    'Spider-Man - All Media Types'],
#   'title': "5 Times Spider-Man Saved an Avenger's Ass (and 1 Time They Saved Him)",
#   'author': ['TunaFishChris'],
#   'fic_id': 7665130,
#   'num_appeared': 1,
#   'primary_dtb': 'to_read',
#   'dtb_types': ['to_read'],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': ['-'],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': ['7 collections some good, BAMF!Peter'],
#   'to_read_rating': ['2'],
#   'title_str': '5timesspidermansavedanavengersassand1timetheysavedhim',
#   'primary_url': 'https://archiveofourown.org/works/7665130',
#   'all_urls': ['https://archiveofourown.org/works/7665130/chapters/17454355']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Batman - All Media Types', 'DCU (Comics)'],
#   'title': '5 Times Tim Spends the Night at Wayne Manor + 1 Time He Comes Home',
#   'author': ['motleyfam'],
#   'fic_id': 35650879,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '5timestimspendsthenightatwaynemanor1timehecomeshome',
#   'primary_url': 'https://archiveofourown.org/works/35650879',
#   'all_urls': ['https://archiveofourown.org/works/35650879']},
#  {'primary_version': 7.0,
#   'version_nums': [7.1, 7.0],
#   'primary_source': 'v7_ffn',
#   'smk_sources': ['v7_ffn', 'v7.1_ffn'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Spider-Man - All Media Types'],
#   'title': "5 Times Tony Didn't Need To Worry About Peter",
#   'author': ['grilledcheesing'],
#   'fic_id': 11467308,
#   'num_appeared': 2,
#   'primary_dtb': 'read',
#   'dtb_types': ['read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [True],
#   'is_subbed': [False],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': ['FALSE'],
#   'categories': ['comfort'],
#   'current_chapter': [],
#   'all_tags': ['.Hurt/Comfort,.Family'],
#   'fic_rating': 2.0,
#   'all_ratings': [2.0],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '5timestonydidntneedtoworryaboutpeter',
#   'primary_url': 'https://archiveofourown.org/works/11467308',
#   'all_urls': ['https://www.archiveofourown.org/works/11467308/chapters/25710738']},
#  {'primary_version': 7.0,
#   'version_nums': [7.1, 7.0],
#   'primary_source': 'v7_ffn',
#   'smk_sources': ['v7_ffn', 'v7.1_ffn'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Avengers (Marvel) - All Media Types',
#    'Spider-Man - All Media Types'],
#   'title': '5 times tony forgot peter was just a kid',
#   'author': ['parkrstark'],
#   'fic_id': 11633874,
#   'num_appeared': 2,
#   'primary_dtb': 'read',
#   'dtb_types': ['read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [True],
#   'is_subbed': [False],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': ['FALSE'],
#   'categories': ['hurt_comfort,famil_dynamic,rainyday'],
#   'current_chapter': [],
#   'all_tags': ['.Hurt/Comfort,.Family,.BAMF'],
#   'fic_rating': 2.0,
#   'all_ratings': [2.0],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '5timestonyforgotpeterwasjustakid',
#   'primary_url': 'https://archiveofourown.org/works/11633874',
#   'all_urls': ['https://www.archiveofourown.org/works/11633874/chapters/26164194']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Marvel Cinematic Universe', 'Spider-Man: Homecoming (2017)'],
#   'title': '5 Times Tony had Too Much Money and One Time Peter Did',
#   'author': ['Fomhair'],
#   'fic_id': 15115712,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '5timestonyhadtoomuchmoneyandonetimepeterdid',
#   'primary_url': 'https://archiveofourown.org/works/15115712',
#   'all_urls': ['https://archiveofourown.org/works/15115712']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['陈情令 | The Untamed (TV)',
#    '魔道祖师 - 墨香铜臭 | Módào Zǔshī - Mòxiāng Tóngxiù'],
#   'title': '60 years',
#   'author': ['maesthicc'],
#   'fic_id': 33236794,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': '60years',
#   'primary_url': 'https://archiveofourown.org/works/33236794',
#   'all_urls': ['https://archiveofourown.org/works/33236794']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_chrome'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Naruto'],
#   'title': 'a beating heart of stone',
#   'author': ['ion (hoodwinked)'],
#   'fic_id': 17229119,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'abeatingheartofstone',
#   'primary_url': 'https://archiveofourown.org/works/17229119',
#   'all_urls': ['https://archiveofourown.org/works/17229119/chapters/40514726']},
#  {'primary_version': 7.0,
#   'version_nums': [8.0, 7.0],
#   'primary_source': 'v7_updates',
#   'smk_sources': ['v7_updates', 'v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Dream SMP', 'Minecraft (Video Game)'],
#   'title': 'A Bird In The Hand',
#   'author': ['SilverWing15'],
#   'fic_id': 35214754,
#   'num_appeared': 3,
#   'primary_dtb': 'read',
#   'dtb_types': ['read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'abirdinthehand',
#   'primary_url': 'https://archiveofourown.org/works/35214754',
#   'all_urls': ['https://archiveofourown.org/works/35214754',
#    'https://archiveofourown.org/works/35214754/chapters/87749599']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Criminal Minds (US TV)',
#    'Fullmetal Alchemist - All Media Types'],
#   'title': 'About Damage, About Pain, About Heartache',
#   'author': ['AngelSelene'],
#   'fic_id': 29962410,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'aboutdamageaboutpainaboutheartache',
#   'primary_url': 'https://archiveofourown.org/works/29962410',
#   'all_urls': ['https://archiveofourown.org/works/29962410']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ["人渣反派自救系统 - 墨香铜臭 | The Scum Villain's Self-Saving System - Mòxiāng Tóngxiù"],
#   'title': 'Absolutely Ineffable',
#   'author': ['Tossawary'],
#   'fic_id': 28236945,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'absolutelyineffable',
#   'primary_url': 'https://archiveofourown.org/works/28236945',
#   'all_urls': ['https://archiveofourown.org/works/28236945']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Good Omens (TV)', 'Good Omens - Neil Gaiman & Terry Pratchett'],
#   'title': 'A Bushel and a Peck',
#   'author': ['thehoyden'],
#   'fic_id': 20609393,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'abushelandapeck',
#   'primary_url': 'https://archiveofourown.org/works/20609393',
#   'all_urls': ['https://archiveofourown.org/works/20609393']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ["人渣反派自救系统 - 墨香铜臭 | The Scum Villain's Self-Saving System - Mòxiāng Tóngxiù"],
#   'title': 'Abyssal Paradise',
#   'author': ['DevinePhoenix'],
#   'fic_id': 26597317,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'abyssalparadise',
#   'primary_url': 'https://archiveofourown.org/works/26597317',
#   'all_urls': ['https://archiveofourown.org/works/26597317']},
#  {'primary_version': 7.0,
#   'version_nums': [8.0, 7.1, 7.0],
#   'primary_source': 'v7_ffn',
#   'smk_sources': ['v7_ffn', 'v7.1_ffn', 'v8_ao3-subs_works', 'v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Final Fantasy XV', 'Final Fantasy XV'],
#   'title': 'A Cat Can Look at a King',
#   'author': ['lithos_saeculum'],
#   'fic_id': 25068775,
#   'num_appeared': 5,
#   'primary_dtb': 'read',
#   'dtb_types': ['read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [False],
#   'is_subbed': [False, True],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': ['FALSE'],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': ['.Hurt/Comfort,.Friendship,.Cats'],
#   'fic_rating': 2.0,
#   'all_ratings': [2.0],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'acatcanlookataking',
#   'primary_url': 'https://archiveofourown.org/works/25068775',
#   'all_urls': ['https://archiveofourown.org/works/25068775/chapters/60721390',
#    'https://archiveofourown.org/works/25068775']},
#  {'primary_version': 7.0,
#   'version_nums': [8.0, 7.1, 7.0],
#   'primary_source': 'v7_ffn',
#   'smk_sources': ['v7_ffn', 'v7.1_ffn', 'v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Sherlock (TV)', 'Sherlock (TV)'],
#   'title': 'Acceptable Behavior',
#   'author': ['bbcatemysoul'],
#   'fic_id': 1031893,
#   'num_appeared': 3,
#   'primary_dtb': 'read',
#   'dtb_types': ['read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [True],
#   'is_subbed': [False],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': ['FALSE'],
#   'categories': ['crack_humor,smile'],
#   'current_chapter': [],
#   'all_tags': ['.Misunderstandings,.Relationship,.Humor,.Fluff',
#    'well_written,.Misunderstandings,.Relationship,.Humor,.Fluff'],
#   'fic_rating': 3.0,
#   'all_ratings': [3.0],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'acceptablebehavior',
#   'primary_url': 'https://archiveofourown.org/works/1031893',
#   'all_urls': ['https://archiveofourown.org/works/1031893']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Star Wars - All Media Types',
#    'Star Wars: The Clone Wars (2008) - All Media Types'],
#   'title': 'Accidentally Irresistible',
#   'author': ['kj_feybarn'],
#   'fic_id': 41959110,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'accidentallyirresistible',
#   'primary_url': 'https://archiveofourown.org/works/41959110',
#   'all_urls': ['https://archiveofourown.org/works/41959110']},
#  {'primary_version': 7.0,
#   'version_nums': [7.1, 7.0],
#   'primary_source': 'v7_ffn',
#   'smk_sources': ['v7_ffn', 'v7.1_ffn'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Teen Wolf (TV)'],
#   'title': 'According to Plan',
#   'author': ['FeelingsDusk'],
#   'fic_id': 6490537,
#   'num_appeared': 2,
#   'primary_dtb': 'read',
#   'dtb_types': ['read'],
#   'fic_series': ['Teen Wolf Bingo'],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [True],
#   'is_subbed': [False],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': ['FALSE'],
#   'categories': ['favorite,rainyday,bamf'],
#   'current_chapter': [],
#   'all_tags': ['well_written,.Time Travel,.BAMF,.Plot,.Plot,.Helping,Steter',
#    '.Time Travel,.BAMF,.Plot,.Action,.Helping,Steter'],
#   'fic_rating': 2.0,
#   'all_ratings': [2.0],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'accordingtoplan',
#   'primary_url': 'https://archiveofourown.org/works/6490537',
#   'all_urls': ['https://archiveofourown.org/works/6490537']},
#  {'primary_version': 7.0,
#   'version_nums': [8.0, 7.0],
#   'primary_source': 'v7_updates',
#   'smk_sources': ['v7_updates', 'v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Teen Wolf (TV)'],
#   'title': 'Accountability',
#   'author': ['withlightning'],
#   'fic_id': 611492,
#   'num_appeared': 2,
#   'primary_dtb': 'to_read',
#   'dtb_types': ['to_read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': ['8k, POV outsiders who think Derek is abusing Stiles, university'],
#   'to_read_rating': [],
#   'title_str': 'accountability',
#   'primary_url': 'https://archiveofourown.org/works/611492',
#   'all_urls': ['https://archiveofourown.org/works/611492']},
#  {'num_appeared': 1,
#   'primary_version': 7.1,
#   'primary_source': 'v7.1_ffn',
#   'primary_dtb': 'read',
#   'fic_id': 2803341,
#   'primary_url': 'https://www.fanfiction.net/s/2803341/1/Accounting-no-Jutsu',
#   'categories': [],
#   'is_bold': None,
#   'fandom_type': [],
#   'fandom': ['Naruto'],
#   'fic_status': None,
#   'title': 'Accounting no Jutsu',
#   'is_coffee': None,
#   'fic_series': [],
#   'author': [''],
#   'length': None,
#   'is_complete': None,
#   'is_subbed': None,
#   'is_backedup': None,
#   'is_bookmarked': None,
#   'in_category': None,
#   'all_tags': [],
#   'current_chapter': '',
#   'fic_rating': None,
#   'to_read_rating': None,
#   'to_read_description': [],
#   'is_finished_inputting_data': False,
#   'ffn_date_updated_2-4-23': [],
#   'ffn_date_added': [],
#   'title_str': 'accountingnojutsu',
#   'locations': ['ffn_net'],
# ...
#   'title_str': 'imfallingforyoureyesbuttheydontknowmeyet',
#   'primary_url': 'https://archiveofourown.org/works/11500380',
#   'all_urls': ['https://archiveofourown.org/works/11500380']},
#  {'primary_version': 7.0,
#   'version_nums': [7.0],
#   'primary_source': [],
#   'smk_sources': ['v7_toread'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['僕のヒーローアカデミア | Boku no Hero Academia | My Hero Academia'],
#   'title': 'Immutability',
#   'author': ['deafmic'],
#   'fic_id': 15958928,
#   'num_appeared': 1,
#   'primary_dtb': 'to_read',
#   'dtb_types': ['to_read'],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': ['re'],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': ['1'],
#   'title_str': 'immutability',
#   'primary_url': 'https://archiveofourown.org/works/15958928',
#   'all_urls': ['https://archiveofourown.org/works/15958928']},
#  {'num_appeared': 1,
#   'primary_version': 7.1,
#   'primary_source': 'v7.1_ffn',
#   'primary_dtb': 'read',
#   'fic_id': 9275180,
#   'primary_url': 'https://www.fanfiction.net/s/9275180/1/I-m-Not-Supposed-to-Talk-to-Strangers',
#   'categories': [],
#   'is_bold': None,
#   'fandom_type': [],
#   'fandom': ['Percy Jackson and the Olympians & Related Fandoms - All Media Types'],
#   'fic_status': None,
#   'title': "I'm Not Supposed to Talk to Strangers",
#   'is_coffee': None,
#   'fic_series': [],
#   'author': ['LoyaltyFalters'],
#   'length': '1',
#   'is_complete': True,
#   'is_subbed': None,
#   'is_backedup': True,
#   'is_bookmarked': None,
#   'in_category': None,
#   'all_tags': ['.Abuse', '.Angst'],
#   'current_chapter': '',
#   'fic_rating': 2.0,
#   'to_read_rating': None,
#   'to_read_description': [],
#   'is_finished_inputting_data': True,
#   'ffn_date_updated_2-4-23': [],
#   'ffn_date_added': [],
#   'title_str': 'imnotsupposedtotalktostrangers',
#   'locations': ['ffn_net'],
#   'smk_sources': ['v7.1_ffn'],
#   'dtb_types': ['read'],
#   'primary_location': 'ffn_net',
#   'all_urls': ['https://www.fanfiction.net/s/9275180/1/I-m-Not-Supposed-to-Talk-to-Strangers'],
#   'version_nums': [7.1]},
#  {'primary_version': 7.0,
#   'version_nums': [7.1, 7.0],
#   'primary_source': 'v7_ffn',
#   'smk_sources': ['v7_ffn', 'v7.1_ffn'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Batman - All Media Types'],
#   'title': "I'm Not Your (Fake) Boyfriend!",
#   'author': ['heartslogos'],
#   'fic_id': 1119108,
#   'num_appeared': 2,
#   'primary_dtb': 'read',
#   'dtb_types': ['read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [True],
#   'is_subbed': [False],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': ['FALSE'],
#   'categories': ['bamf'],
#   'current_chapter': [],
#   'all_tags': ['.Humor', 'well_written,.Humor'],
#   'fic_rating': 3.0,
#   'all_ratings': [3.0],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'imnotyourfakeboyfriend',
#   'primary_url': 'https://archiveofourown.org/works/1119108',
#   'all_urls': ['https://archiveofourown.org/works/1119108']},
#  {'primary_version': 7.0,
#   'version_nums': [8.0, 7.0],
#   'primary_source': 'v7_updates',
#   'smk_sources': ['v7_updates', 'v8_ao3-subs_works', 'v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['陈情令 | The Untamed (TV)',
#    '魔道祖师 - 墨香铜臭 | Módào Zǔshī - Mòxiāng Tóngxiù',
#    '魔道祖师 - 墨香铜臭 | Módào Zǔshī - Mòxiāng Tóngxiù'],
#   'title': 'Impenetrable Walls',
#   'author': ['Gina3'],
#   'fic_id': 24111895,
#   'num_appeared': 4,
#   'primary_dtb': 'read',
#   'dtb_types': ['read', 'cont_read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [False],
#   'is_subbed': [True],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': ['ch 24, the concubine!WWX w/ the crates of flutes from a pining LWJ'],
#   'to_read_rating': [],
#   'title_str': 'impenetrablewalls',
#   'primary_url': 'https://archiveofourown.org/works/24111895',
#   'all_urls': ['https://archiveofourown.org/works/24111895/chapters/58044802',
#    'https://archiveofourown.org/works/24111895']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Among Us (Video Game)'],
#   'title': 'impostor syndrome',
#   'author': ['arahir'],
#   'fic_id': 26671084,
#   'num_appeared': 2,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'impostorsyndrome',
#   'primary_url': 'https://archiveofourown.org/works/26671084',
#   'all_urls': ['http://www.archiveofourown.org/works/26671084',
#    'https://archiveofourown.org/works/26671084']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Criminal Minds (US TV)',
#    'Fullmetal Alchemist - All Media Types'],
#   'title': 'Impressions - a Wreckage Sidefic',
#   'author': ['AngelSelene'],
#   'fic_id': 26513050,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'impressionsawreckagesidefic',
#   'primary_url': 'https://archiveofourown.org/works/26513050',
#   'all_urls': ['https://archiveofourown.org/works/26513050']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Batman - All Media Types',
#    'DCU',
#    'DCU (Comics)',
#    'Young Justice (Comics)'],
#   'title': 'I’m Pretty Sure Tim Steals Clothes: An Elaboration In The Form Of A Long Fic',
#   'author': ['PrinceJakeFireCake'],
#   'fic_id': 37942261,
#   'num_appeared': 2,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'imprettysuretimstealsclothesanelaborationintheformofalongfic',
#   'primary_url': 'https://archiveofourown.org/works/37942261',
#   'all_urls': ['https://archiveofourown.org/works/37942261/chapters/95071180#workskin',
#    'https://archiveofourown.org/works/37942261/chapters/94757776']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Harry Potter - J. K. Rowling'],
#   'title': "I'm sippin' tea in yo hood",
#   'author': ['Ourliazo'],
#   'fic_id': 39323223,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'imsippinteainyohood',
#   'primary_url': 'https://archiveofourown.org/works/39323223',
#   'all_urls': ['https://archiveofourown.org/works/39323223/chapters/98405988']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['陈情令 | The Untamed (TV)'],
#   'title': 'In Another Life',
#   'author': ['SingingInTheRaiin'],
#   'fic_id': 24442852,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'inanotherlife',
#   'primary_url': 'https://archiveofourown.org/works/24442852',
#   'all_urls': ['https://archiveofourown.org/collections/SATISFYINGwellwrittenMDZSfics/works/24442852']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_chrome'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Marvel', 'Marvel Cinematic Universe', 'Thor (Movies)'],
#   'title': 'In Another Lifetime',
#   'author': ['DragonflyxParodies'],
#   'fic_id': 16782406,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'inanotherlifetime',
#   'primary_url': 'https://archiveofourown.org/works/16782406',
#   'all_urls': ['https://archiveofourown.org/works/16782406']},
#  {'primary_version': 7.0,
#   'version_nums': [7.0],
#   'primary_source': [],
#   'smk_sources': ['v7_toread'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Naruto'],
#   'title': 'In Bond and Blood',
#   'author': ['thehoyden'],
#   'fic_id': 212688,
#   'num_appeared': 1,
#   'primary_dtb': 'to_read',
#   'dtb_types': ['to_read'],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [True],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': ['re'],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': ['KakaIru marriage of convenience for kid!fic Naruto, smut, sweet dreams'],
#   'to_read_rating': ['sd'],
#   'title_str': 'inbondandblood',
#   'primary_url': 'https://archiveofourown.org/works/212688',
#   'all_urls': ['https://archiveofourown.org/works/212688']},
#  {'primary_version': 8.0,
#   'version_nums': [8.0],
#   'primary_source': [],
#   'smk_sources': ['v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Wiedźmin | The Witcher (Video Game)'],
#   'title': 'Incomplete',
#   'author': ['astolat'],
#   'fic_id': 9391280,
#   'num_appeared': 1,
#   'primary_dtb': '',
#   'dtb_types': [],
#   'fic_series': [],
#   'is_bold': [],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': [],
#   'to_read_rating': [],
#   'title_str': 'incomplete',
#   'primary_url': 'https://archiveofourown.org/works/9391280',
#   'all_urls': ['https://archiveofourown.org/works/9391280']},
#  {'primary_version': 7.0,
#   'version_nums': [8.0, 7.0],
#   'primary_source': 'v7_updates',
#   'smk_sources': ['v7_updates', 'v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['陈情令 | The Untamed (TV)',
#    '魔道祖师 - 墨香铜臭 | Módào Zǔshī - Mòxiāng Tóngxiù'],
#   'title': 'I need my space',
#   'author': ['deliciousblizzardshark'],
#   'fic_id': 31546508,
#   'num_appeared': 2,
#   'primary_dtb': 'to_read',
#   'dtb_types': ['to_read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': ['6k, WangXian astonuat roommates'],
#   'to_read_rating': [],
#   'title_str': 'ineedmyspace',
#   'primary_url': 'https://archiveofourown.org/works/31546508',
#   'all_urls': ['https://archiveofourown.org/works/31546508']},
#  {'primary_version': 7.0,
#   'version_nums': [8.0, 7.0],
#   'primary_source': 'v7_updates',
#   'smk_sources': ['v7_updates', 'v8_local_files'],
#   'primary_location': 'ao3',
#   'locations': ['ao3'],
#   'work_type': 'fic',
#   'fandom': ['Harry Potter - J. K. Rowling'],
#   'title': 'Inertia',
#   'author': ['BonesOfBirdWings'],
#   'fic_id': 21998470,
#   'num_appeared': 3,
#   'primary_dtb': 'to_read',
#   'dtb_types': ['to_read'],
#   'fic_series': [],
#   'is_bold': [False],
#   'is_coffee': [],
#   'is_complete': [],
#   'is_subbed': [],
#   'is_bookmarked': [],
#   'is_finished_inputting_data': [],
#   'is_backedup': [],
#   'categories': [],
#   'current_chapter': [],
#   'all_tags': [],
#   'fic_rating': None,
#   'all_ratings': [],
#   'fandom_type': [],
#   'ffn_date_added': [],
#   'ffn_date_updated_2-4-23': [],
#   'fic_status': [],
#   'in_category': [],
#   'readability_status': ['readable'],
#   'to_read_description': ['21k, by BonesOfBirdWings, mentor Snape, worldbuilding, smart HP'],
#   'to_read_rating': [],
#   'title_str': 'inertia',
#   'primary_url': 'https://archiveofourown.org/works/21998470',
#   'all_urls': ['https://archiveofourown.org/works/21998470/chapters/52495645',
#    'https://archiveofourown.org/works/21998470']},
#  ...]

# %%
doubles = []
def match_fics(text_unmerged, url_unmerged, title_str):
    text = [fic for fic in text_unmerged if fic['title_str'] == title_str]
    url = [fic for fic in url_unmerged if fic['title_str'] == title_str]

    # Error & null case handling
    if len(text) > 1 or len(url) > 1:
        error_message = f"\nERROR: title_str: {title_str} has {len(text)} fics in text_unmerged and {len(url)} fics in url_unmerged!"
        print(error_message)
        doubles.append(title_str)
        return
        # raise Exception(error_message)
    elif len(text) == 0 and len(url) == 0:
        raise Exception(f"ERROR: not fic found in either text or url dict with title_str: {title_str}")

    # Set dict variables
    text = text[0] if len(text) != 0 else {}
    url = url[0] if len(url) != 0 else {}

    # No need to check matches if only one fic
    if text == {} or url == {}:
        return [text, url]

    # text_fandom, url_fandom = set(text['fandom']), set(url['fandom'])
    text_authors = set([author.lower() for author in text['author'] if author != ""])
    text_authors = sorted(list(set(text_authors)))
    url_authors = set([author.lower() for author in url['author'] if author != ""])
    url_authors = sorted(list(set(url_authors)))
    
    # , url_authors = set(text['author']), set(url['author'])
    

    # if text_authors != set() and url_authors != set():
    #     if 

    # if text_fandom != url_fandom:
    #     print(f"{title_str} (text --- url): {text_fandom} --- {url_fandom}")
        

    
    
    # if not set(text['fandom']) == set(url['fandom']):
    #     print(f'{title_str} (text, url), fandoms: {set(text["fandom"])}, {set(url["fandom"])}')

    if text_authors != url_authors and text_authors != [] and url_authors != []:
        print(f'{title_str} (text, url), authors: {text_authors}, {url_authors}')
        print()

# %% [markdown]
# unmerge:
# - antithesis ['cywscross', 'oceanbreeze7'],
# - basicinstincts (text, url), authors: ['miss_lv'], ['manic_intent']
# - bite (text, url), authors: ['blackkat', 'esama'], ['blackkat']

# %%
misspellings = [{'right': 'amournfulhowlinthenight', 'wrong': 'amournfulhowlinthedark'},
                {'right': 'kitsune foxfire', 'wrong': 'kitsune firefox'},
                {'right': 'RIGHT', 'wrong': 'WRONG'},
                {'right': 'RIGHT', 'wrong': 'WRONG'},
                {'right': 'RIGHT', 'wrong': 'WRONG'},
                {'right': 'RIGHT', 'wrong': 'WRONG'},
                {'right': 'RIGHT', 'wrong': 'WRONG'},
                {'right': 'RIGHT', 'wrong': 'WRONG'},
                {'right': 'RIGHT', 'wrong': 'WRONG'},
                {'right': 'RIGHT', 'wrong': 'WRONG'},
                {'right': 'RIGHT', 'wrong': 'WRONG'},
                {'right': 'RIGHT', 'wrong': 'WRONG'},
               ]

# %% [markdown]
# Strip whitespace
# split psudeonyms into two authors

# %% [markdown]
# - ariadne83 somehowunbroken
# - drelfina evocates -> drelfina, evocates
# - mikimoo pentapus
# - firefright pentapus
# - aventria iluxia ->
# - aventriailuxia -> aventria iluxia
# - PSEUDONYM: ceiaofsilence
# - PSEUDONYM: tsume_yuki, tsume yuki
# - PSEUDONYM: ['luki', 'luki (kelpiecodyne)'
# - lala_the_lessermisminorqwerty224 -> lala_the_lesser misminorqwerty224

# %%
# MATCH FIC TESTING
url_title_strs = [fic['title_str'] for fic in url_unmerged if 'error' not in fic]
text_title_strs = [fic['title_str'] for fic in text_unmerged]
all_title_strs = sorted(list(set(url_title_strs+text_title_strs)))

merged_fics = []
for title_str in all_title_strs:
    match_fics(text_unmerged, url_unmerged, title_str)
# Out:
# adoptedbydefault (text, url), authors: ['kitsune firefox'], ['kitsune firefox', 'kitsune foxfire']
#
# afterthestorm (text, url), authors: ['ariadne83', 'somehowunbroken'], ['ariadne83somehowunbroken']
#
# ahundredspringsfloweasttowardsthesea (text, url), authors: ['drelfina', 'evocates'], ['drelfina evocates']
#
# anotherperfectcatastrophe (text, url), authors: ['mikimoo', 'pentapus'], ['mikimoopentapus']
#
# antithesis (text, url), authors: ['cywscross', 'oceanbreeze7'], ['oceanbreeze7']
#
# anunexpectedfind (text, url), authors: ['firefright', 'pentapus'], ['firefrightpentapus']
#
# basicinstincts (text, url), authors: ['miss_lv'], ['manic_intent']
#
# becomingthephoenix (text, url), authors: ['branch', 'lodestone'], ['branch']
#
# bite (text, url), authors: ['blackkat', 'esama'], ['blackkat']
#
# blue (text, url), authors: ['wynnebat'], ['bealeciphers']
#
# brothers (text, url), authors: ['heartslogos'], ['grumpyhedgehogs']
#
# cardiacarrest (text, url), authors: ['amournfulhowlinthedark'], ['amournfulhowlinthenight']
#
# catalysis (text, url), authors: ['aventria', 'iluxia'], ['aventria iluxia', 'aventriailuxia', 'teh twinnesses presents']
#
# childsplay (text, url), authors: ['spicyjarvis'], ['whistle mist']
#
# cirruscloud (text, url), authors: ['silenceia'], ['ceiaofsilence', 'silenceia']
#
# cosmicstrings (text, url), authors: ['tsume_yuki'], ['tsume yuki']
#
# cursed (text, url), authors: ['astolat'], ['devilsoupe']
#
# daydream (text, url), authors: ['luki'], ['luki (kelpiecodyne)']
#
# dontkissandtell (text, url), authors: ['luki'], ['luki', 'luki (kelpiecodyne)']
#
# doover (text, url), authors: ['kyogre', 'maldoror_chant'], ['kyogre']
#
# dragonlord (text, url), authors: ['esama'], ['dragonspectre']
#
# familyreunions (text, url), authors: ['lokasennahiddleston'], ['astralgolds']
#
# feral (text, url), authors: ['kitsune firefox'], ['sniperanon (the_big_reveal)']
#
# goodvibrations (text, url), authors: ['softestpunk'], ['feynite']
#
# hiddeninplainsight (text, url), authors: ['isabella1948'], ['isabella1948', 'peridot15']
#
# howtofileform39b (text, url), authors: ['b', 'thehoyden'], ['thehoyden']
#
# howwemetyourmother (text, url), authors: ['deliriumdescending'], ['deliriumdescending', 'everliv']
#
# iwastransmigratedasasword (text, url), authors: ['lala_the_lesser', 'misminor', 'qwerty224'], ['lala_the_lessermisminorqwerty224']
#
# kingfisherfeathers (text, url), authors: ['anonymous'], ['      anonymous    ']
#
# leadingmybrotherstothepromisedland (text, url), authors: ['raberba_girl'], ['raberba girl (raberba_girl)']
#
# lockedindigital (text, url), authors: ['roguedruid'], ['roguedruid (icarius51)']
#
# matchmakermatchmaker (text, url), authors: ['watermelonsmellinfellon'], ['prosodiical']
#
# monogatari (text, url), authors: ['superpol'], ['bimmyou']
#
# natural (text, url), authors: ['esama', 'setepenre_set'], ['esama']
#
# notthistimefate (text, url), authors: ["couer al'aran"], ["coeur al'aran", "couer al'aran"]
#
# pride (text, url), authors: ['astolat'], ['manic_intent']
#
# problemchild (text, url), authors: ['a_reflective_projection', 'tgp'], ['tgp']
#
# quidproquo (text, url), authors: ['dira sudis'], ['rillrill']
#
# redacted (text, url), authors: ['cherei'], ['chierei']
#
# redrobinhood (text, url), authors: ['shanastoryteller'], ['candlebreak']
#
# safeguard (text, url), authors: ['esama'], ['aloneintherain']
#
# secondchances (text, url), authors: ['superiordragonlorde'], ['glacis']
#
# shelter (text, url), authors: ['raberba_girl'], ['raberba girl (raberba_girl)']
#
# speechless (text, url), authors: ['tierfaal'], ['tierfal']
#
# springfever (text, url), authors: ['miss_lv'], ['maldoro_chant']
#
# standards (text, url), authors: ['taizi'], ['taisi', 'taizi']
#
# strawberriesandhonor (text, url), authors: ['whisperingdarkness'], ['whispering darkness']
#
# symbiosis (text, url), authors: ['constructivewriter'], ['emmar']
#
# taketwo (text, url), authors: ['esama'], ['bundibird']
#
# thebeginningofwisdom (text, url), authors: ['nirejseki'], ['nirejsekirobininthelabyrinth (nirejseki)']
#
# thehotline (text, url), authors: ['aloneintherain'], ['aliciarosefantasy aloneintherain', 'aliciarosefantasyaloneintherain']
#
# thekeytosurvival (text, url), authors: ['jessoterick', 'mintgator'], ['jesso']
#
# thelifeandtimesofhatakekakashinukenin (text, url), authors: ['whisperingdarkness'], ['whispering darkness']
#
# thelivesworthsaving (text, url), authors: ['cywsphyre'], ['cywsaphyre', 'cywsaphyre nikkicross', 'cywsphyre']
#
# thetempesttemptation (text, url), authors: ['luki'], ['luki', 'luki (kelpiecodyne)']
#
# victimofcircumstance (text, url), authors: ['chalcet'], ['chalcet', 'chalcet (orphan_account)']
#
# wanderer (text, url), authors: ['cywsphyre'], ['cywsaphyre', 'cywsphyre']
#
# whatgoesaround (text, url), authors: ['wix'], ['kouriarashi']
#
# withnothingonmytongue (text, url), authors: ['sunshineinwriting'], ['sunshine_sparrow']

# %%
def combine_dedup(text_unmerged, url_unmerged, colName, debug=False):
    if colName not in text_unmerged and colName not in url_unmerged:
        return None
    
    text = [] if colName not in text_unmerged else text_unmerged[colName]
    url = [] if colName not in url_unmerged else url_unmerged[colName]
    if debug: print(f"{colName} (text, url): ", text, url)

    text = text if isinstance(text, list) else [text]
    url = url if isinstance(url, list) else [url]
    
    combined_list = text + url
    if debug: print(f"- combined_list: {combined_list}")
        
        
    cleaned_list = [ele for ele in combined_list if ele != None and not pd.isna(ele) and ele != ""]
    if debug: print(f"- cleaned_list: {cleaned_list}")
        
    dedup_list = list(set(cleaned_list))
    if debug: print(f"- dedup_list: {dedup_list}")
    
    return sorted(dedup_list)
    
def bool_clean(text_unmerged, url_unmerged, colName):
    clean_bools = combine_dedup(text_unmerged, url_unmerged, colName)
    return None if len(clean_bools) == 0 else any(clean_bools)

doubles = []
def merge_fic(text_unmerged, url_unmerged, title_str):
    # Get relevant fics from url & text dicts
    text = [fic for fic in text_unmerged if fic['title_str'] == title_str]
    url = [fic for fic in url_unmerged if fic['title_str'] == title_str]

    # Error & null case handling
    if len(text) > 1 or len(url) > 1:
        error_message = f"\nERROR: title_str: {title_str} has {len(text)} fics in text_unmerged and {len(url)} fics in url_unmerged!"
        print(error_message)
        doubles.append(title_str)
        return
        # raise Exception(error_message)
    elif len(text) == 0 and len(url) == 0:
        raise Exception(f"ERROR: not fic found in either fict with title_str: {title_str}")

    # Set dict variables
    text = text[0] if len(text) != 0 else {}
    url = url[0] if len(url) != 0 else {}

    # Cleaning relevant keys
    clean_dtbs = combine_dedup(text, url, 'dtb_types')
    sorted_dtbs = sorted(clean_dtbs, key=lambda dtb: DTB_ORDER[dtb])

    clean_ratings = combine_dedup(text, url, 'fic_rating')
    avg_rating = None if len(clean_ratings) == 0 else round(sum(clean_ratings)/len(clean_ratings), 2)

    clean_locs = combine_dedup(text, url, 'locations')
    sorted_locations = sorted(clean_locs, key=lambda loc: LOCATION_ORDER[loc])

    clean_sources = combine_dedup(text, url, 'smk_sources')
    sorted_sources = sorted(clean_sources, key = lambda source: float(source.split('_')[0][1:]))

    sorted_versions = combine_dedup(text, url, 'in_category')

    sorted_urls = combine_dedup(text, url, 'all_urls')
    primary_url = None if len(sorted_urls) == 0 else sorted_urls[0]
    if 'fic_id' in url:
        primary_url = "https://archiveofourown.org/works/" + str(url['fic_id'])

    title = url['title'] if (url.get('title', None) is not None and len(url['title']) != 0) else text['title']

    num_appeared_total = text.get('num_appeared', 0) + url.get('num_appeared', 0)
    num_appeared_total = num_appeared_total if num_appeared_total != 0 else None

    total = {'all_ratings': url.get('all_ratings', None),
            'all_tags': combine_dedup(text, url, 'all_tags'),
            'all_urls': sorted_urls,
            'author': combine_dedup(text, url, 'author'),
            'categories': combine_dedup(text, url, 'categories'),
            'current_chapter': combine_dedup(text, url, 'current_chapter'),
            'dtb_types': sorted_dtbs,
            'early_ratings': text.get('early_ratings', None),
            'fandom': combine_dedup(text, url, 'fandom'),
            'fandom_type': url.get('fandom_type', None),
            'ffn_date_added': url.get('ffn_date_added', None),
            'ffn_date_updated_2-4-23': url.get('ffn_date_updated_2-4-23', None),
            'fic_id': url.get('fic_id', None),
            'fic_rating': avg_rating,
            'fic_series': combine_dedup(text, url, 'fic_series'),
            'fic_status': combine_dedup(text, url, 'fic_status'),
            'in_category': combine_dedup(text, url, 'in_category'),
            'is_backedup': bool_clean(text, url, 'is_backedup'),
            'is_bold': bool_clean(text, url, 'is_bold'),
            'is_bookmarked': bool_clean(text, url, 'is_bookmarked'),
            'is_coffee': bool_clean(text, url, 'is_coffee'),
            'is_complete': bool_clean(text, url, 'is_complete'),
            'is_finished_inputting_data': bool_clean(text, url, 'is_finished_inputting_data'),
            'is_subbed': bool_clean(text, url, 'is_subbed'),
            'length': text.get('length', None),
            'locations': sorted_locations,
            'num_appeared_total': num_appeared_total,
            'num_appeared_text': text.get('num_appeared', None),
            'num_appeared_url': url.get('num_appeared', None),
            'primary_dtb': None if len(sorted_dtbs) == 0 else sorted_dtbs[0],
            'primary_location': None if len(sorted_locations) == 0 else sorted_locations[0],
            'primary_source': None if len(sorted_sources) == 0 else sorted_sources[0],
            'primary_url': primary_url,
            'primary_versions': None if len(sorted_versions) == 0 else sorted_versions[0],
            'readability_status': url.get('readability_status', None),
            'smk_sources': sorted_sources,
            'title': title,
            'title_str': title_str,
            'to_read_description': combine_dedup(text, url, 'to_read_description'),
            'to_read_rating': url.get('to_read_rating', None),
            'version_nums': sorted_versions,
            'work_type': url.get('work_type', None),
           }

    if 'error' in url:
        total['error'] = url['error']

    print(".", end="")
    return total


# merge_fic(text_unmerged, url_unmerged, 'cestlavie')

# %%
# Code to merge all s5 fic text + url 
url_title_strs = [fic['title_str'] for fic in url_unmerged if 'error' not in fic]
text_title_strs = [fic['title_str'] for fic in text_unmerged]
all_title_strs = sorted(list(set(url_title_strs+text_title_strs)))

merged_fics = []
for title_str in all_title_strs:
    new_fic = merge_fic(text_unmerged, url_unmerged, title_str)
    merged_fics.append(new_fic)
print("SEE: variable 'doubles' to see a list of all title_strs of dups")
# Out:
# ................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................ ...

# %% [markdown]
# # WORKSPACE

# %%
def fic_equal(row1, row2) -> bool:
    """
    Takes two fic or series rows from a database (df).
    Compares them to determine if they're the same fic.
    Returns a boolean of whether or not they're equal (bool).
    """
    # Get titles boolean
    title1 = str(row1['title']).lower().strip()
    title2 = str(row2['title']).lower().strip()
    same_title = title1 == title2
    
    # Get authors boolean (strip, lower, not empty)
    authlist1 = [] if pd.isnull(row1['author']) else row1['author'].split(',')
    authlist2 = [] if pd.isnull(row2['author']) else row2['author'].split(',')
    author1 = set([auth.lower().strip() for auth in authlist1 if auth != ''])
    author2 = set([auth.lower().strip() for auth in authlist2 if auth != ''])
    
    same_author = (author1 == author2) or (not author1 and not author2)
    absent_author = not author1 or not author2

    # Get locations boolean
    same_location = (row1['location'] == row2['location']) or \
        pd.isnull(row1['location']) or pd.isnull(row2['location'])
    
    # Get fandoms boolean
    same_fandoms = False
    if not pd.isnull(row1['fandom']) and not pd.isnull(row2['fandom']):
        fandom1 = [fan.strip() for fan in row1['fandom'].split(',')]
        fandom2 = [fan.strip() for fan in row2['fandom'].split(',')]
        diff = set(fandom1) ^ set(fandom2)
        same_fandoms = (len(diff) == 0) or (diff == {'dcu', 'batman'}) or \
            (diff == {'spiderman', 'avengers'})
        
    
    # print(f'same_title: {same_title}, same_fandoms: {same_fandoms}, same_author: {same_author}, absent_author: {absent_author}')
    # print()
    return same_title and same_fandoms and (same_author or (absent_author and same_location))
